# %% [markdown]
# # Template cells (March 17th)

# %%
# !pip install pyxdf
# In your other Python file (e.g., analysis.py)
from LabRecorder_Viewer import XDFExplorer

# %% [markdown]
# ## To change for every new files

# %%
explorer = XDFExplorer("./sample_data/block_Default.xdf")
# Out:
# ✅ Loaded XDF file: ./sample_data/block_Default.xdf
# 📊 Found 43 streams
# 🕒 Experiment start (t0): 42021.366 s
#
# --- Stream Summary ---
# [0] source_id: MD-V7-0000027 	    | SCR_AMP 	 | type: SCRAmplitude 	 | channels: 1 	 | Fs: 0.0 Hz 	 | samples: 38 	 | time: 46.58–258.91s
# [1] source_id: MD-V7-0000027 	    | THERM 	 | type: Thermopile 	 | channels: 1 	 | Fs: 7.5 Hz 	 | samples: 2047 	 | time: 0.20–273.21s
# [2] source_id: LiveAmpSN-054907-0281_STETriggerIn 	    | LiveAmpSN-054907-0281-STETriggerIn 	 | type: Markers 	 | channels: 1 	 | Fs: 0.0 Hz 	 | samples: 0 	 |
# [3] source_id: MD-V7-0000192 	    | SCR_AMP 	 | type: SCRAmplitude 	 | channels: 1 	 | Fs: 0.0 Hz 	 | samples: 12 	 | time: 5.59–208.14s
# [4] source_id: MD-V7-0000027 	    | PPG_IR 	 | type: PPGInfrared 	 | channels: 1 	 | Fs: 25.0 Hz 	 | samples: 6782 	 | time: 0.10–273.11s
# [5] source_id: MD-V7-0000192 	    | ACC_Z 	 | type: AccelerometerZ 	 | channels: 1 	 | Fs: 25.0 Hz 	 | samples: 6833 	 | time: 0.09–273.08s
# ...

# %%
explorer.print_detailed_summary()
# Out:
# ...
# 📊 DETAILED STREAM ANALYSIS
# ...
#
# [0] 📡 EMOTIBIT
#     Name: SCR_AMP
#     Source ID: MD-V7-0000027
#     Type: SCRAmplitude
#     Channels: 1
#     Sample Rate: 0.0 Hz
#     Samples: 38
#     Duration: 212.33s
#     Time Range: 46.58s - 258.91s
#     Data Type: float32
#     Value Range: 0.000 - 9999.347
#
# [1] 📡 EMOTIBIT
#     Name: THERM
#     Source ID: MD-V7-0000027
#     Type: Thermopile
#     Channels: 1
#     Sample Rate: 7.5 Hz
#     Samples: 2,047
#     Duration: 273.01s
#     Time Range: 0.20s - 273.21s
#     Data Type: float32
#     Value Range: 28.349 - 33.627
#
# [2] 📊 OTHER
#     Name: LiveAmpSN-054907-0281-STETriggerIn
#     Source ID: LiveAmpSN-054907-0281_STETriggerIn
#     Type: Markers
#     Channels: 1
#     Sample Rate: 0.0 Hz
#     Samples: 0
#     Duration: 0.00s
#     Time Range: 0.00s - 0.00s
#
# [3] 📡 EMOTIBIT
#     Name: SCR_AMP
#     Source ID: MD-V7-0000192
#     Type: SCRAmplitude
#     Channels: 1
#     Sample Rate: 0.0 Hz
#     Samples: 12
# ...

# %% [markdown]
# The cell we want to copy paste to get a quick view
#
#
# *   Automatically find the indeces for a list of stream we'll always want to take a look
# *

# %%
explorer.print_marker_timeline()
# Out:
# ⏰ COMPLETE MARKER TIMELINE
# ...
# ⚠️ No markers found in any stream

# %%
explorer.plot_markers(idx=2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_14351/611921957.py in <cell line: 0>()
# ----> 1 explorer.plot_markers(idx=2)
#
# /content/LabRecorder_Viewer.py in plot_markers(self, idx)
#     302         plt.title(f"🪧 Marker Stream — {name}")
#     303         plt.xlabel("Time (s)")
# --> 304         plt.xlim([0, ts.max()])
#     305         plt.yticks([])
#     306         plt.tight_layout()
#
# /usr/local/lib/python3.12/dist-packages/numpy/_core/_methods.py in _amax(a, axis, out, keepdims, initial, where)
#      42 def _amax(a, axis=None, out=None, keepdims=False,
#      43           initial=_NoValue, where=True):
# ---> 44     return umr_maximum(a, axis, None, out, keepdims, initial, where)
#      45
#      46 def _amin(a, axis=None, out=None, keepdims=False,
#
# ValueError: zero-size array to reduction operation maximum which has no identity
# ...

# %%
explorer.plot_emotibit_all()
# Out:
# 📦 Found 38 EmotiBit continuous stream(s).
# /content/LabRecorder_Viewer.py:450: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /content/LabRecorder_Viewer.py:450: UserWarning: Tight layout not applied. tight_layout cannot make Axes height small enough to accommodate all Axes decorations.
#   plt.tight_layout()
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
explorer.plot_streams_enhanced(
    byLabel = ["027-PPG_GRN", "192-PPG_GRN"]
    max_duration=50
    )

# %%
explorer.plot_streams_enhanced(
    channels_per_stream = [[0], [0], [0], [16]],
    indices=[40, 42, 33, 32],
    labels=["EDA1", "EDA2", "VAmp", "LiveA"],
    max_duration=50
    )

# %%
explorer.plot_streams_enhanced(
    channels_per_stream = [[0], [0], [0], [16]],
    indices=[34, 41, 33, 32],
    labels=["MV92", "MV27", "VAmp", "LiveA"],
    # max_duration=5
    )

# %% [markdown]
# # Template cells (27 Feb)

# %%
# !pip install pyxdf
# In your other Python file (e.g., analysis.py)
from LabRecorder_Viewer import XDFExplorer

# %% [markdown]
# ## To change for every new files

# %%
explorer = XDFExplorer("./sample_data/DY_005.xdf")
# Out:
# ✅ Loaded XDF file: ./sample_data/DY_005.xdf
# 📊 Found 44 streams
# 🕒 Experiment start (t0): 4159.088 s
#
# --- Stream Summary ---
# [0] source_id: MD-V7-0000192 	    | SCR_RIS 	 | type: SCRRiseTime 	 | channels: 1 	 | Fs: 0.0 Hz 	 | samples: 1 	 | time: 82.56–82.56s
# [1] source_id: MD-V7-0000192 	    | PPG_RED 	 | type: PPGRed 	 | channels: 1 	 | Fs: 25.0 Hz 	 | samples: 4859 	 | time: 0.02–195.57s
# [2] source_id: MD-V7-0000027 	    | GYRO_Z 	 | type: GyroscopeZ 	 | channels: 1 	 | Fs: 25.0 Hz 	 | samples: 4970 	 | time: 0.05–195.61s
# [3] source_id: MD-V7-0000027 	    | ACC_Z 	 | type: AccelerometerZ 	 | channels: 1 	 | Fs: 25.0 Hz 	 | samples: 4970 	 | time: 0.04–195.60s
# [4] source_id: MD-V7-0000192 	    | GYRO_Z 	 | type: GyroscopeZ 	 | channels: 1 	 | Fs: 25.0 Hz 	 | samples: 4897 	 | time: 0.03–195.56s
# [5] source_id: MD-V7-0000192 	    | EDA 	 | type: EDA 	 | channels: 1 	 | Fs: 15.0 Hz 	 | samples: 2934 	 | time: 0.04–195.56s
# ...

# %%
explorer.print_detailed_summary()
# Out:
# ...
# 📊 DETAILED STREAM ANALYSIS
# ...
#
# [0] 📡 EMOTIBIT
#     Name: SCR_RIS
#     Source ID: MD-V7-0000192
#     Type: SCRRiseTime
#     Channels: 1
#     Sample Rate: 0.0 Hz
#     Samples: 1
#     Duration: 0.00s
#     Time Range: 82.56s - 82.56s
#     Data Type: float32
#     Value Range: 0.200 - 0.200
#
# [1] 📡 EMOTIBIT
#     Name: PPG_RED
#     Source ID: MD-V7-0000192
#     Type: PPGRed
#     Channels: 1
#     Sample Rate: 25.0 Hz
#     Samples: 4,859
#     Duration: 195.55s
#     Time Range: 0.02s - 195.57s
#     Data Type: float32
#     Value Range: 141202.000 - 143064.000
#
# [2] 📡 EMOTIBIT
#     Name: GYRO_Z
#     Source ID: MD-V7-0000027
#     Type: GyroscopeZ
#     Channels: 1
#     Sample Rate: 25.0 Hz
#     Samples: 4,970
#     Duration: 195.56s
#     Time Range: 0.05s - 195.61s
#     Data Type: float32
#     Value Range: -328.003 - 202.820
#
# [3] 📡 EMOTIBIT
#     Name: ACC_Z
#     Source ID: MD-V7-0000027
#     Type: AccelerometerZ
#     Channels: 1
#     Sample Rate: 25.0 Hz
# ...

# %% [markdown]
# The cell we want to copy paste to get a quick view
#
#
# *   Automatically find the indeces for a list of stream we'll always want to take a look
# *

# %%
explorer.print_marker_timeline()
# Out:
# ⏰ COMPLETE MARKER TIMELINE
# ...
#     Time | Type            | Block | Trial | Image                | Stream
# --------------------------------------------------------------------------------
#    24.93s | BLOCK_START     | 1     | N/A   | N/A                  | Experiment Markers
#    89.61s | TRIAL_START     | 1     | 1     | N/A                  | Experiment Markers
#    89.61s | IMAGE           | 1     | 1     | Mother 1.jpg         | Experiment Markers
#    89.72s | SPACEBAR        | 1     | 1     | N/A                  | Experiment Markers
#    92.06s | P               | 1     | 1     | N/A                  | Experiment Markers
#    92.18s | SPACEBAR        | 1     | 1     | N/A                  | Experiment Markers
#    92.66s | SPACEBAR        | 1     | 1     | N/A                  | Experiment Markers
#    95.58s | TRIAL_START     | 1     | 2     | N/A                  | Experiment Markers
#    95.58s | IMAGE           | 1     | 2     | Thunderstorm 2.jpg   | Experiment Markers
# ...

# %%
explorer.plot_markers(idx=23)
# Out:
# /content/LabRecorder_Viewer.py:306: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()

# %%
explorer.plot_emotibit_all()
# Out:
# 📦 Found 38 EmotiBit continuous stream(s).
# /content/LabRecorder_Viewer.py:450: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /content/LabRecorder_Viewer.py:450: UserWarning: Tight layout not applied. tight_layout cannot make Axes height small enough to accommodate all Axes decorations.
#   plt.tight_layout()
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
explorer.plot_streams_enhanced(
    channels_per_stream = [[0], [0], [0], [16]],
    indices=[1, 13, 38, 34],
    labels=["MV92", "MV27", "VAmp", "LiveA"],
    # max_duration=5
    )

# %% [markdown]
# # Template cells (20 Feb)

# %%
# !pip install pyxdf
# In your other Python file (e.g., analysis.py)
from LabRecorder_Viewer import XDFExplorer

# %% [markdown]
# ## To change for every new files

# %%
explorer = XDFExplorer("./sample_data/please2.xdf")
# Out:
# ✅ Loaded XDF file: ./sample_data/please2.xdf
# 📊 Found 20 streams
# 🕒 Experiment start (t0): 656922.616 s
#
# --- Stream Summary ---
# [0] source_id: MD-V7-0000027 	    | MAG_Y 	 | type: MagnetometerY 	 | channels: 1 	 | Fs: 25.0 Hz 	 | samples: 2500 	 | time: 0.05–99.18s
# [1] source_id: MD-V7-0000027 	    | PPG_RED 	 | type: PPGRed 	 | channels: 1 	 | Fs: 25.0 Hz 	 | samples: 2451 	 | time: 0.12–99.14s
# [2] source_id: MD-V7-0000027 	    | MAG_X 	 | type: MagnetometerX 	 | channels: 1 	 | Fs: 25.0 Hz 	 | samples: 2500 	 | time: 0.05–99.18s
# [3] source_id: MD-V7-0000027 	    | PPG_IR 	 | type: PPGInfrared 	 | channels: 1 	 | Fs: 25.0 Hz 	 | samples: 2451 	 | time: 0.12–99.14s
# [4] source_id: MD-V7-0000027 	    | ACC_Y 	 | type: AccelerometerY 	 | channels: 1 	 | Fs: 25.0 Hz 	 | samples: 2504 	 | time: 0.16–99.14s
# [5] source_id: MD-V7-0000027 	    | THERM 	 | type: Thermopile 	 | channels: 1 	 | Fs: 7.5 Hz 	 | samples: 740 	 | time: 0.01–99.10s
# ...

# %%
explorer.print_detailed_summary()
# Out:
# ...
# 📊 DETAILED STREAM ANALYSIS
# ...
#
# [0] 📡 EMOTIBIT
#     Name: MAG_Y
#     Source ID: MD-V7-0000027
#     Type: MagnetometerY
#     Channels: 1
#     Sample Rate: 25.0 Hz
#     Samples: 2,500
#     Duration: 99.13s
#     Time Range: 0.05s - 99.18s
#     Data Type: float32
#     Value Range: -30.000 - -15.000
#
# [1] 📡 EMOTIBIT
#     Name: PPG_RED
#     Source ID: MD-V7-0000027
#     Type: PPGRed
#     Channels: 1
#     Sample Rate: 25.0 Hz
#     Samples: 2,451
#     Duration: 99.02s
#     Time Range: 0.12s - 99.14s
#     Data Type: float32
#     Value Range: 146932.000 - 150714.000
#
# [2] 📡 EMOTIBIT
#     Name: MAG_X
#     Source ID: MD-V7-0000027
#     Type: MagnetometerX
#     Channels: 1
#     Sample Rate: 25.0 Hz
#     Samples: 2,500
#     Duration: 99.13s
#     Time Range: 0.05s - 99.18s
#     Data Type: float32
#     Value Range: 26.000 - 45.000
#
# [3] 📡 EMOTIBIT
#     Name: PPG_IR
#     Source ID: MD-V7-0000027
#     Type: PPGInfrared
#     Channels: 1
#     Sample Rate: 25.0 Hz
# ...

# %% [markdown]
# The cell we want to copy paste to get a quick view
#
#
# *   Automatically find the indeces for a list of stream we'll always want to take a look
# *

# %%
explorer.print_marker_timeline()
# Out:
# ⏰ COMPLETE MARKER TIMELINE
# ...
#     Time | Type            | Block | Trial | Image                | Stream
# --------------------------------------------------------------------------------
#    17.34s | BEFORE_BLOCK  | N/A   | N/A   | N/A                  | Experiment Markers
#    22.18s | BLOCK_START     | 1     | N/A   | N/A                  | Experiment Markers
#    23.32s | TRIAL_START     | 1     | 1     | N/A                  | Experiment Markers
#    23.32s | IMAGE           | 1     | 1     | Lightning 1.jpg      | Experiment Markers
#    23.42s | SPACEBAR        | 1     | 1     | N/A                  | Experiment Markers
#    26.34s | P               | 1     | 1     | N/A                  | Experiment Markers
#    29.31s | TRIAL_START     | 1     | 2     | N/A                  | Experiment Markers
#    29.31s | IMAGE           | 1     | 2     | Office supplies 4... | Experiment Markers
#    30.69s | SPACEBAR        | 1     | 2     | N/A                  | Experiment Markers
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
explorer.plot_markers(idx=7)
# Out:
# /content/LabRecorder_Viewer.py:306: UserWarning: Glyph 129703 (\N{PLACARD}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /content/LabRecorder_Viewer.py:306: UserWarning: Glyph 127 () missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /content/LabRecorder_Viewer.py:306: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 129703 (\N{PLACARD}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 127 () missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
explorer.plot_emotibit_all()
# Out:
# 📦 Found 19 EmotiBit continuous stream(s).
# /content/LabRecorder_Viewer.py:450: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
explorer.plot_streams_enhanced(indices=[14, 7])
# Out:
# /content/LabRecorder_Viewer.py:450: UserWarning: Glyph 127 () missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 127 () missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# # Log

# %% [markdown]
# TODO
# - figure ouyt the channel auto selection for the Bain produc streams
# -

# %% [markdown]
# ## Jan 23rd

# %%
# In your other Python file (e.g., analysis.py)
from LabRecorder_Viewer import XDFExplorer

# Create an instance
explorer = XDFExplorer("./sample_data/T001.xdf")
# Out:
# Print detailed markers for block 1
#
# ✅ Loaded XDF file: ./sample_data/T001.xdf
# 📊 Found 44 streams
# 🕒 Experiment start (t0): 627514.348 s
#
# --- Stream Summary ---
# [0] source_id: MD-V7-0000027 	    | HR 	 | type: HeartRate 	 | channels: 1 	 | Fs: 0.0 Hz 	 | samples: 110 	 | time: 0.87–109.49s
# [1] source_id: MD-V7-0000027 	    | TEMP1 	 | type: Temperature 	 | channels: 1 	 | Fs: 7.5 Hz 	 | samples: 822 	 | time: 0.10–109.56s
# [2] source_id: MD-V7-0000192 	    | SCR_FREQ 	 | type: SCRFrequency 	 | channels: 1 	 | Fs: 0.0 Hz 	 | samples: 329 	 | time: 0.05–109.52s
# [3] source_id: MD-V7-0000027 	    | MAG_Z 	 | type: MagnetometerZ 	 | channels: 1 	 | Fs: 25.0 Hz 	 | samples: 2785 	 | time: 0.01–109.57s
# [4] source_id: LiveAmpSN-054907-0281_DeviceTrigger 	    | LiveAmpSN-054907-0281-DeviceTrigger 	 | type: Markers 	 | channels: 1 	 | Fs: 0.0 Hz 	 | samples: 0 	 |
# ...

# %%
explorer.analyze_data_quality()
# Out:
# 🔍 DATA QUALITY ANALYSIS
# ...
# [0] HR:
#     Duration: 108.61s
#     Markers: 110
#     Interval range: 0.296s - 2.950s
#     Avg interval: 0.996s
#     Quality: ✅ EXCELLENT
# [1] TEMP1:
#     Duration: 109.46s
#     Completeness: 100.1%
#     Data gaps: 0
#     Quality: ✅ EXCELLENT
# [2] SCR_FREQ:
#     Duration: 109.46s
#     Markers: 329
#     Interval range: 0.111s - 0.570s
#     Avg interval: 0.334s
#     Quality: ✅ EXCELLENT
# [3] MAG_Z:
#     Duration: 109.56s
#     Completeness: 101.7%
#     Data gaps: 0
#     Quality: ✅ EXCELLENT
# [4] LiveAmpSN-054907-0281-DeviceTrigger: ❌ EMPTY STREAM
# [5] PPG_GRN:
#     Duration: 109.51s
#     Completeness: 99.5%
#     Data gaps: 0
#     Quality: ✅ EXCELLENT
# [6] GYRO_Z:
#     Duration: 109.63s
#     Completeness: 100.2%
#     Data gaps: 0
#     Quality: ✅ EXCELLENT
# [7] EDA:
#     Duration: 109.52s
#     Completeness: 100.1%
#     Data gaps: 0
#     Quality: ✅ EXCELLENT
# [8] LiveAmpSN-054907-0281-STETriggerIn: ❌ EMPTY STREAM
# ...

# %%
explorer.print_detailed_summary()
# Out:
# ...
# 📊 DETAILED STREAM ANALYSIS
# ...
#
# [0] 📡 EMOTIBIT
#     Name: HR
#     Source ID: MD-V7-0000027
#     Type: HeartRate
#     Channels: 1
#     Sample Rate: 0.0 Hz
#     Samples: 110
#     Duration: 108.61s
#     Time Range: 0.87s - 109.49s
#     Data Type: float32
#     Value Range: 50.290 - 96.100
#
# [1] 📡 EMOTIBIT
#     Name: TEMP1
#     Source ID: MD-V7-0000027
#     Type: Temperature
#     Channels: 1
#     Sample Rate: 7.5 Hz
#     Samples: 822
#     Duration: 109.46s
#     Time Range: 0.10s - 109.56s
#     Data Type: float32
#     Value Range: 32.669 - 33.967
#
# [2] 📡 EMOTIBIT
#     Name: SCR_FREQ
#     Source ID: MD-V7-0000192
#     Type: SCRFrequency
#     Channels: 1
#     Sample Rate: 0.0 Hz
#     Samples: 329
#     Duration: 109.46s
#     Time Range: 0.05s - 109.52s
#     Data Type: float32
#     Value Range: 0.072 - 3.259
#
# [3] 📡 EMOTIBIT
#     Name: MAG_Z
#     Source ID: MD-V7-0000027
#     Type: MagnetometerZ
#     Channels: 1
#     Sample Rate: 25.0 Hz
# ...

# %%
labels = [
    "PPG_RED_S",
    "PPG_RED_F",
    "HR-S",
    "HR-F",
    "Markers",
    ]
explorer.plot_streams_enhanced(
    indices= [11, 32, 40, 10],
    channels_per_stream=[[0], [0], [0], [0]],  # Stream's channels
    max_duration=9000,  # Adjust as needed
    labels=labels,
    show_markers=True
)
explorer.print_marker_timeline()
# Out:
# /Users/franckporteous/Documents/MindHive/EmotiBit NYU Validation Study/evs-experimentalSoftware/LabRecorder_Viewer.py:450: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /Users/franckporteous/miniforge3/envs/pyStable/lib/python3.11/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# ⏰ COMPLETE MARKER TIMELINE
# ...
#     Time | Type            | Block | Trial | Image                | Stream
# --------------------------------------------------------------------------------
#     5.25s | BLOCK_START     | 1     | N/A   | N/A                  | Experiment Markers
#    15.30s | TRIAL_START     | 1     | 1     | N/A                  | Experiment Markers
#    15.30s | IMAGE           | 1     | 1     | Lion 1.jpg           | Experiment Markers
# ...

# %% [markdown]
# ## Jan 23rd

# %%
# In your other Python file (e.g., analysis.py)
from LabRecorder_Viewer import XDFExplorer

# Create an instance
explorer = XDFExplorer("./data/block_Default.xdf")
# Out:
# ✅ Loaded XDF file: ./data/block_Default.xdf
# 📊 Found 20 streams
# 🕒 Experiment start (t0): 600866.683 s
#
# --- Stream Summary ---
# [0] source_id: MD-V7-0000027 	    | EDA 	 | type: EDA 	 | channels: 1 	 | Fs: 15.0 Hz 	 | samples: 2303 	 | time: 0.04–153.49s
# [1] source_id: MD-V7-0000027 	    | ACC_Z 	 | type: AccelerometerZ 	 | channels: 1 	 | Fs: 25.0 Hz 	 | samples: 3901 	 | time: 0.03–153.53s
# [2] source_id: MD-V7-0000027 	    | PPG_GRN 	 | type: PPGGreen 	 | channels: 1 	 | Fs: 25.0 Hz 	 | samples: 3815 	 | time: 0.02–153.51s
# [3] source_id: MD-V7-0000027 	    | GYRO_Y 	 | type: GyroscopeY 	 | channels: 1 	 | Fs: 25.0 Hz 	 | samples: 3901 	 | time: 0.03–153.53s
# [4] source_id: MD-V7-0000027 	    | HR 	 | type: HeartRate 	 | channels: 1 	 | Fs: 0.0 Hz 	 | samples: 205 	 | time: 0.55–153.47s
# [5] source_id: MD-V7-0000027 	    | MAG_X 	 | type: MagnetometerX 	 | channels: 1 	 | Fs: 25.0 Hz 	 | samples: 3901 	 | time: 0.04–153.54s
# ...

# %%
explorer.analyze_data_quality()
# Out:
# 🔍 DATA QUALITY ANALYSIS
# ...
# [0] EDA:
#     Duration: 153.45s
#     Completeness: 100.1%
#     Data gaps: 0
#     Quality: ✅ EXCELLENT
# [1] ACC_Z:
#     Duration: 153.50s
#     Completeness: 101.7%
#     Data gaps: 0
#     Quality: ✅ EXCELLENT
# [2] PPG_GRN:
#     Duration: 153.48s
#     Completeness: 99.4%
#     Data gaps: 0
#     Quality: ✅ EXCELLENT
# [3] GYRO_Y:
#     Duration: 153.50s
#     Completeness: 101.7%
#     Data gaps: 0
#     Quality: ✅ EXCELLENT
# [4] HR:
#     Duration: 152.92s
#     Markers: 205
#     Interval range: 0.232s - 1.269s
#     Avg interval: 0.750s
#     Quality: ✅ EXCELLENT
# [5] MAG_X:
#     Duration: 153.50s
#     Completeness: 101.7%
#     Data gaps: 0
#     Quality: ✅ EXCELLENT
# [6] PPG_IR:
#     Duration: 153.48s
#     Completeness: 99.4%
#     Data gaps: 0
#     Quality: ✅ EXCELLENT
# [7] MAG_Y:
#     Duration: 153.54s
#     Completeness: 101.7%
#     Data gaps: 0
#     Quality: ✅ EXCELLENT
# [8] ACC_Y:
#     Duration: 153.50s
# ...

# %%
labels = [
    # "PPG_IR",
    "PPG_RED",
    # "EDA",
    # "HR",
    "HR",
    "Markers",
    ]
explorer.plot_streams_enhanced(
    indices= [12, 4, 19],
    channels_per_stream=[[0], [0], [0]],  # Each stream has 1 channel
    max_duration=9000,  # Adjust as needed
    labels=labels,
    show_markers=True
)
explorer.print_marker_timeline()
# Out:
# /Users/franckporteous/Documents/MindHive/EmotiBit NYU Validation Study/evs-experimentalSoftware/LabRecorder_Viewer.py:450: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /Users/franckporteous/miniforge3/envs/pyStable/lib/python3.11/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# ⏰ COMPLETE MARKER TIMELINE
# ...
#     Time | Type            | Block | Trial | Image                | Stream
# --------------------------------------------------------------------------------
#    57.84s | BLOCK_START     | 1     | N/A   | N/A                  | Experiment Markers
#    61.88s | TRIAL_START     | 1     | 1     | N/A                  | Experiment Markers
#    61.88s | IMAGE           | 1     | 1     | Lake 13.jpg          | Experiment Markers
# ...

# %%
# In your other Python file (e.g., analysis.py)
from LabRecorder_Viewer import XDFExplorer

# Create an instance
explorer = XDFExplorer("./data/block_Default.xdf")
# Out:
# ✅ Loaded XDF file: ./data/block_Default.xdf
# 📊 Found 20 streams
# 🕒 Experiment start (t0): 600866.683 s
#
# --- Stream Summary ---
# [0] source_id: MD-V7-0000027 	    | EDA 	 | type: EDA 	 | channels: 1 	 | Fs: 15.0 Hz 	 | samples: 2303 	 | time: 0.04–153.49s
# [1] source_id: MD-V7-0000027 	    | ACC_Z 	 | type: AccelerometerZ 	 | channels: 1 	 | Fs: 25.0 Hz 	 | samples: 3901 	 | time: 0.03–153.53s
# [2] source_id: MD-V7-0000027 	    | PPG_GRN 	 | type: PPGGreen 	 | channels: 1 	 | Fs: 25.0 Hz 	 | samples: 3815 	 | time: 0.02–153.51s
# [3] source_id: MD-V7-0000027 	    | GYRO_Y 	 | type: GyroscopeY 	 | channels: 1 	 | Fs: 25.0 Hz 	 | samples: 3901 	 | time: 0.03–153.53s
# [4] source_id: MD-V7-0000027 	    | HR 	 | type: HeartRate 	 | channels: 1 	 | Fs: 0.0 Hz 	 | samples: 205 	 | time: 0.55–153.47s
# [5] source_id: MD-V7-0000027 	    | MAG_X 	 | type: MagnetometerX 	 | channels: 1 	 | Fs: 25.0 Hz 	 | samples: 3901 	 | time: 0.04–153.54s
# ...

# %%
explorer.analyze_data_quality()
# Out:
# 🔍 DATA QUALITY ANALYSIS
# ...
# [0] EDA:
#     Duration: 153.45s
#     Completeness: 100.1%
#     Data gaps: 0
#     Quality: ✅ EXCELLENT
# [1] ACC_Z:
#     Duration: 153.50s
#     Completeness: 101.7%
#     Data gaps: 0
#     Quality: ✅ EXCELLENT
# [2] PPG_GRN:
#     Duration: 153.48s
#     Completeness: 99.4%
#     Data gaps: 0
#     Quality: ✅ EXCELLENT
# [3] GYRO_Y:
#     Duration: 153.50s
#     Completeness: 101.7%
#     Data gaps: 0
#     Quality: ✅ EXCELLENT
# [4] HR:
#     Duration: 152.92s
#     Markers: 205
#     Interval range: 0.232s - 1.269s
#     Avg interval: 0.750s
#     Quality: ✅ EXCELLENT
# [5] MAG_X:
#     Duration: 153.50s
#     Completeness: 101.7%
#     Data gaps: 0
#     Quality: ✅ EXCELLENT
# [6] PPG_IR:
#     Duration: 153.48s
#     Completeness: 99.4%
#     Data gaps: 0
#     Quality: ✅ EXCELLENT
# [7] MAG_Y:
#     Duration: 153.54s
#     Completeness: 101.7%
#     Data gaps: 0
#     Quality: ✅ EXCELLENT
# [8] ACC_Y:
#     Duration: 153.50s
# ...

# %%
labels = [
    # "PPG_IR",
    "PPG_RED",
    # "EDA",
    # "HR",
    "HR",
    "Markers",
    ]
explorer.plot_streams_enhanced(
    indices= [12, 4, 19],
    channels_per_stream=[[0], [0], [0]],  # Each stream has 1 channel
    max_duration=9000,  # Adjust as needed
    labels=labels,
    show_markers=True
)
explorer.print_marker_timeline()
# Out:
# /Users/franckporteous/Documents/MindHive/EmotiBit NYU Validation Study/evs-experimentalSoftware/LabRecorder_Viewer.py:450: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /Users/franckporteous/miniforge3/envs/pyStable/lib/python3.11/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# ⏰ COMPLETE MARKER TIMELINE
# ...
#     Time | Type            | Block | Trial | Image                | Stream
# --------------------------------------------------------------------------------
#    57.84s | BLOCK_START     | 1     | N/A   | N/A                  | Experiment Markers
#    61.88s | TRIAL_START     | 1     | 1     | N/A                  | Experiment Markers
#    61.88s | IMAGE           | 1     | 1     | Lake 13.jpg          | Experiment Markers
# ...

# %% [markdown]
# ## Nov 13th

# %% [markdown]
# ### V-Amp + Emotibit (real data)

# %%
# In your other Python file (e.g., analysis.py)
from LabRecorder_Viewer import XDFExplorer

# Create an instance
explorer = XDFExplorer("./data/R001 (V-Amp+Emotibit).xdf")
# Out:
# Stream 18: Calculated effective sampling rate 291.0622 Hz is different from specified rate 500.0000 Hz.
# Stream 18: Segments and clock-segments differ
# ✅ Loaded XDF file: ./data/R001 (V-Amp+Emotibit).xdf
# 📊 Found 22 streams
# 🕒 Experiment start (t0): 13320.354 s
#
# --- Stream Summary ---
# [0] source_id: MD-V7-0000192 	    | ACC_Y 	 | type: AccelerometerY 	 | channels: 1 	 | Fs: 25.0 Hz 	 | samples: 3019 	 | time: 0.00–120.53s
# [1] source_id: MD-V7-0000192 	    | SCR_RIS 	 | type: SCRRiseTime 	 | channels: 1 	 | Fs: 0.0 Hz 	 | samples: 34 	 | time: 8.53–106.80s
# [2] source_id: MD-V7-0000192 	    | MAG_Z 	 | type: MagnetometerZ 	 | channels: 1 	 | Fs: 25.0 Hz 	 | samples: 3016 	 | time: 0.01–120.46s
# [3] source_id: MD-V7-0000192 	    | MAG_X 	 | type: MagnetometerX 	 | channels: 1 	 | Fs: 25.0 Hz 	 | samples: 3016 	 | time: 0.00–120.46s
# [4] source_id: MD-V7-0000192 	    | MAG_Y 	 | type: MagnetometerY 	 | channels: 1 	 | Fs: 25.0 Hz 	 | samples: 3016 	 | time: 0.01–120.46s
# ...

# %%
# Use the methods
explorer.analyze_data_quality()
# Out:
# 🔍 DATA QUALITY ANALYSIS
# ...
# [0] ACC_Y:
#     Duration: 120.53s
#     Completeness: 100.2%
#     Data gaps: 0
#     Quality: ✅ EXCELLENT
# [1] SCR_RIS:
#     Duration: 98.27s
#     Markers: 34
#     Interval range: 0.167s - 16.333s
#     Avg interval: 2.978s
#     Quality: ✅ EXCELLENT
# [2] MAG_Z:
#     Duration: 120.45s
#     Completeness: 100.2%
#     Data gaps: 0
#     Quality: ✅ EXCELLENT
# [3] MAG_X:
#     Duration: 120.45s
#     Completeness: 100.2%
#     Data gaps: 0
#     Quality: ✅ EXCELLENT
# [4] MAG_Y:
#     Duration: 120.45s
#     Completeness: 100.2%
#     Data gaps: 0
#     Quality: ✅ EXCELLENT
# [5] GYRO_Y:
#     Duration: 120.52s
#     Completeness: 100.2%
#     Data gaps: 0
#     Quality: ✅ EXCELLENT
# [6] BrainVision RDA Markers: ❌ EMPTY STREAM
# [7] Markers:
#     Duration: 109.88s
#     Markers: 40
#     Interval range: 0.000s - 17.030s
#     Avg interval: 2.817s
#     Quality: ✅ EXCELLENT
# [8] GYRO_X:
#     Duration: 120.53s
#     Completeness: 100.2%
# ...

# %%
explorer.list_streams_by_source_id('RDA 127.0.0.1:51244')
# Out:
# 📡 STREAMS FOR SOURCE ID: RDA 127.0.0.1:51244
# ...
#
# [2] RDA 127.0.0.1:51244
#     [9] BrainVision RDA: EEG (500.0 Hz)

# %%
explorer.export_stream_info()
# Out:
# 📄 Stream analysis exported to: ./devLogs/stream_analysis_22_streams.txt

# %%
explorer.print_detailed_summary()
# Out:
# ...
# 📊 DETAILED STREAM ANALYSIS
# ...
#
# [0] 📡 EMOTIBIT
#     Name: ACC_Y
#     Source ID: MD-V7-0000192
#     Type: AccelerometerY
#     Channels: 1
#     Sample Rate: 25.0 Hz
#     Samples: 3,019
#     Duration: 120.53s
#     Time Range: 0.00s - 120.53s
#     Data Type: float32
#     Value Range: 0.125 - 0.506
#
# [1] 📡 EMOTIBIT
#     Name: SCR_RIS
#     Source ID: MD-V7-0000192
#     Type: SCRRiseTime
#     Channels: 1
#     Sample Rate: 0.0 Hz
#     Samples: 34
#     Duration: 98.27s
#     Time Range: 8.53s - 106.80s
#     Data Type: float32
#     Value Range: 0.067 - 3.400
#
# [2] 📡 EMOTIBIT
#     Name: MAG_Z
#     Source ID: MD-V7-0000192
#     Type: MagnetometerZ
#     Channels: 1
#     Sample Rate: 25.0 Hz
#     Samples: 3,016
#     Duration: 120.45s
#     Time Range: 0.01s - 120.46s
#     Data Type: float32
#     Value Range: -24.000 - 2.000
#
# [3] 📡 EMOTIBIT
#     Name: MAG_X
#     Source ID: MD-V7-0000192
#     Type: MagnetometerX
#     Channels: 1
#     Sample Rate: 25.0 Hz
# ...

# %%
labels = [
    "BrainVision RDA (VAMP)",
    # "PPG_RED",
    # "EDA",
    # "HR",
    # "PPGGreen",
    # "LiveAmpSN-054907-0281",
    ]

# Plot them
explorer.plot_streams_enhanced(
    indices= [9],
    channels_per_stream=[[9]],  # Each stream has 1 channel
    max_duration=9000,  # Adjust as needed
    labels=labels,
    show_markers=True
)
explorer.print_marker_timeline()
# Out:
# ⏰ COMPLETE MARKER TIMELINE
# ...
#     Time | Type            | Block | Trial | Image                | Stream
# --------------------------------------------------------------------------------
#     6.73s | SPACEBAR_PRESSED_RT1763067853.220s | N/A   | N/A   | N/A                  | Markers
#     7.04s | SPACEBAR_PRESSED_RT1763067853.532s | N/A   | N/A   | N/A                  | Markers
#     8.27s | BLOCK_START     | 1     | N/A   | N/A                  | Markers
#    25.30s | TRIAL_START     | 1     | 1     | N/A                  | Markers
#    25.30s | IMAGE           | 1     | 1     | Fire hydrant 2.jpg   | Markers
#    25.41s | SPACEBAR        | 1     | 1     | N/A                  | Markers
#    27.42s | SPACEBAR        | 1     | 1     | N/A                  | Markers
#    29.31s | TRIAL_START     | 1     | 2     | N/A                  | Markers
#    29.31s | IMAGE           | 1     | 2     | Jail 4.jpg           | Markers
# ...

# %%
labels = [
    # "PPG_IR",
    "PPG_RED",
    # "EDA",
    # "HR",
    # "PPGGreen",
    "LiveAmpSN-054907-0281",
    ]
explorer.plot_streams_enhanced(
    indices= [10, 22],
    channels_per_stream=[[0], [0]],  # Each stream has 1 channel
    max_duration=9000,  # Adjust as needed
    labels=labels,
    show_markers=True
)
explorer.print_marker_timeline()
# Out:
# ⏰ COMPLETE MARKER TIMELINE
# ...
#     Time | Type            | Block | Trial | Image                | Stream
# --------------------------------------------------------------------------------
#     1.60s | BLOCK_START     | 1     | N/A   | N/A                  | Markers
#     4.55s | TRIAL_START     | 1     | 1     | N/A                  | Markers
#     4.55s | IMAGE           | 1     | 1     | Jail 2.jpg           | Markers
#     4.66s | SPACEBAR        | 1     | 1     | N/A                  | Markers
#     6.19s | SPACEBAR        | 1     | 1     | N/A                  | Markers
#     8.56s | TRIAL_START     | 1     | 2     | N/A                  | Markers
#     8.56s | IMAGE           | 1     | 2     | Street 5.jpg         | Markers
#     9.97s | SPACEBAR        | 1     | 2     | N/A                  | Markers
#    12.56s | TRIAL_START     | 1     | 3     | N/A                  | Markers
#    12.56s | IMAGE           | 1     | 3     | Camping 2.jpg        | Markers
# ...

# %%
# #%%
# # See all available blocks with statistics
# explorer.list_all_block_ids()

# # Print details for block 1
# print("Print detailed markers for block 1")
# explorer.print_marker_timeline(block_id=1)

# # Print details for block 2
# print("Print detailed markers for block 2")
# explorer.print_marker_timeline(block_id=2)

# # See all markers across all blocks
# print("See all markers across all blocks")
# explorer.print_marker_timeline()
# # In your other Python file (e.g., analysis.py)
# from LabRecorder_Viewer import XDFExplorer

# # Create an instance
# explorer = XDFExplorer("./data/TEST_2_Emotibit.xdf")

# # Use the methods
# explorer.list_all_block_ids()
# block_data = explorer.extract_block_data(2)
# explorer.analyze_block_data(block_data)
# explorer.analyze_data_quality()
# explorer.list_streams_by_source_id('MD-V7-0000192')
# explorer.list_streams_by_source_id('MD-V7-0000027')
# explorer.export_stream_info()
# explorer.print_detailed_summary()
# # Create labels with source_id for clarity
# labels = ["MD-V7-0000192 GYRO_Z", "MD-V7-0000027 GYRO_Z"]

# # Plot them
# explorer.plot_streams_enhanced(
#     indices= [3, 12],
#     channels_per_stream=[[0], [0]],  # Each stream has 1 channel
#     max_duration=90,  # Adjust as needed
#     labels=labels,
#     show_markers=True
# )
# explorer.print_marker_timeline()

# #%%
# # See all available blocks with statistics
# explorer.list_all_block_ids()

# # Print details for block 1
# print("Print detailed markers for block 1")
# explorer.print_marker_timeline(block_id=1)

# # Print details for block 2
# print("Print detailed markers for block 2")
# explorer.print_marker_timeline(block_id=2)

# # See all markers across all blocks
# print("See all markers across all blocks")
# explorer.print_marker_timeline()
# Out:
# ⏰ COMPLETE MARKER TIMELINE
# ...
#     Time | Type            | Block | Trial | Image                | Stream
# --------------------------------------------------------------------------------
#     1.60s | BLOCK_START     | 1     | N/A   | N/A                  | Markers
#     4.55s | TRIAL_START     | 1     | 1     | N/A                  | Markers
#     4.55s | IMAGE           | 1     | 1     | Jail 2.jpg           | Markers
#     4.66s | SPACEBAR        | 1     | 1     | N/A                  | Markers
#     6.19s | SPACEBAR        | 1     | 1     | N/A                  | Markers
#     8.56s | TRIAL_START     | 1     | 2     | N/A                  | Markers
#     8.56s | IMAGE           | 1     | 2     | Street 5.jpg         | Markers
#     9.97s | SPACEBAR        | 1     | 2     | N/A                  | Markers
#    12.56s | TRIAL_START     | 1     | 3     | N/A                  | Markers
#    12.56s | IMAGE           | 1     | 3     | Camping 2.jpg        | Markers
# ...

# %% [markdown]
# ### Live-Amp + Emotibit (real data)

# %%
# In your other Python file (e.g., analysis.py)
from LabRecorder_Viewer import XDFExplorer

# Create an instance
explorer = XDFExplorer("./data/R002 (Live-Amp+Emotibit).xdf")
# Out:
# Stream 4: Segments and clock-segments differ
# ✅ Loaded XDF file: ./data/R002 (Live-Amp+Emotibit).xdf
# 📊 Found 23 streams
# 🕒 Experiment start (t0): 15003.393 s
#
# --- Stream Summary ---
# [0] source_id: MD-V7-0000192 	    | SCR_AMP 	 | type: SCRAmplitude 	 | channels: 1 	 | Fs: 0.0 Hz 	 | samples: 22 	 | time: 5.68–75.11s
# [1] source_id: LiveAmpSN-054907-0281_DeviceTrigger 	    | LiveAmpSN-054907-0281-DeviceTrigger 	 | type: Markers 	 | channels: 1 	 | Fs: 0.0 Hz 	 | samples: 0 	 |
# [2] source_id: MD-V7-0000192 	    | SCR_FREQ 	 | type: SCRFrequency 	 | channels: 1 	 | Fs: 0.0 Hz 	 | samples: 248 	 | time: 0.03–82.33s
# [3] source_id: LiveAmpSN-054907-0281_STETriggerIn 	    | LiveAmpSN-054907-0281-STETriggerIn 	 | type: Markers 	 | channels: 1 	 | Fs: 0.0 Hz 	 | samples: 0 	 |
# [4] source_id: MD-V7-0000192 	    | SCR_RIS 	 | type: SCRRiseTime 	 | channels: 1 	 | Fs: 0.0 Hz 	 | samples: 22 	 | time: 5.68–75.11s
# ...

# %%
# Use the methods
explorer.analyze_data_quality()
# Out:
# 🔍 DATA QUALITY ANALYSIS
# ...
# [0] SCR_AMP:
#     Duration: 69.43s
#     Markers: 22
#     Interval range: 0.217s - 28.934s
#     Avg interval: 3.306s
#     Quality: ✅ EXCELLENT
# [1] LiveAmpSN-054907-0281-DeviceTrigger: ❌ EMPTY STREAM
# [2] SCR_FREQ:
#     Duration: 82.30s
#     Markers: 248
#     Interval range: 0.150s - 0.467s
#     Avg interval: 0.333s
#     Quality: ✅ EXCELLENT
# [3] LiveAmpSN-054907-0281-STETriggerIn: ❌ EMPTY STREAM
# [4] SCR_RIS:
#     Duration: 69.43s
#     Markers: 22
#     Interval range: 0.217s - 28.934s
#     Avg interval: 3.306s
#     Quality: ✅ EXCELLENT
# [5] PPG_IR:
#     Duration: 82.53s
#     Completeness: 99.5%
#     Data gaps: 0
#     Quality: ✅ EXCELLENT
# [6] GYRO_Y:
#     Duration: 82.54s
#     Completeness: 100.2%
#     Data gaps: 0
#     Quality: ✅ EXCELLENT
# [7] MAG_X:
#     Duration: 82.54s
#     Completeness: 100.2%
#     Data gaps: 0
#     Quality: ✅ EXCELLENT
# [8] Markers:
#     Duration: 79.00s
#     Markers: 38
# ...

# %%
explorer.list_streams_by_source_id('LiveAmpSN-054907-0281')
# Out:
# 📡 STREAMS FOR SOURCE ID: LiveAmpSN-054907-0281
# ...
#
# [1] LiveAmpSN-054907-0281
#     [22] LiveAmpSN-054907-0281: EEG (500.0 Hz)

# %%
explorer.export_stream_info()
# Out:
# 📄 Stream analysis exported to: ./devLogs/stream_analysis_23_streams.txt

# %%
explorer.print_detailed_summary()
# Out:
# ...
# 📊 DETAILED STREAM ANALYSIS
# ...
#
# [0] 📡 EMOTIBIT
#     Name: SCR_AMP
#     Source ID: MD-V7-0000192
#     Type: SCRAmplitude
#     Channels: 1
#     Sample Rate: 0.0 Hz
#     Samples: 22
#     Duration: 69.43s
#     Time Range: 5.68s - 75.11s
#     Data Type: float32
#     Value Range: 0.000 - 0.047
#
# [1] 📊 OTHER
#     Name: LiveAmpSN-054907-0281-DeviceTrigger
#     Source ID: LiveAmpSN-054907-0281_DeviceTrigger
#     Type: Markers
#     Channels: 1
#     Sample Rate: 0.0 Hz
#     Samples: 0
#     Duration: 0.00s
#     Time Range: 0.00s - 0.00s
#
# [2] 📡 EMOTIBIT
#     Name: SCR_FREQ
#     Source ID: MD-V7-0000192
#     Type: SCRFrequency
#     Channels: 1
#     Sample Rate: 0.0 Hz
#     Samples: 248
#     Duration: 82.30s
#     Time Range: 0.03s - 82.33s
#     Data Type: float32
#     Value Range: 8.847 - 31.046
#
# [3] 📊 OTHER
#     Name: LiveAmpSN-054907-0281-STETriggerIn
#     Source ID: LiveAmpSN-054907-0281_STETriggerIn
#     Type: Markers
#     Channels: 1
# ...

# %%
labels = [
    "PPG_IR",
    "PPG_RED",
    "EDA",
    "HR",
    "PPGGreen",
    "LiveAmpSN-054907-0281",
    ]

# Plot them
explorer.plot_streams_enhanced(
    indices= [5, 10, 13, 16, 18, 22],
    channels_per_stream=[[0], [0], [0], [0], [0], [0]],  # Each stream has 1 channel
    max_duration=9000,  # Adjust as needed
    labels=labels,
    show_markers=True
)
explorer.print_marker_timeline()
# Out:
# ⏰ COMPLETE MARKER TIMELINE
# ...
#     Time | Type            | Block | Trial | Image                | Stream
# --------------------------------------------------------------------------------
#     1.60s | BLOCK_START     | 1     | N/A   | N/A                  | Markers
#     4.55s | TRIAL_START     | 1     | 1     | N/A                  | Markers
#     4.55s | IMAGE           | 1     | 1     | Jail 2.jpg           | Markers
#     4.66s | SPACEBAR        | 1     | 1     | N/A                  | Markers
#     6.19s | SPACEBAR        | 1     | 1     | N/A                  | Markers
#     8.56s | TRIAL_START     | 1     | 2     | N/A                  | Markers
#     8.56s | IMAGE           | 1     | 2     | Street 5.jpg         | Markers
#     9.97s | SPACEBAR        | 1     | 2     | N/A                  | Markers
#    12.56s | TRIAL_START     | 1     | 3     | N/A                  | Markers
#    12.56s | IMAGE           | 1     | 3     | Camping 2.jpg        | Markers
# ...

# %%
labels = [
    # "PPG_IR",
    "PPG_RED",
    # "EDA",
    # "HR",
    # "PPGGreen",
    "LiveAmpSN-054907-0281",
    ]
explorer.plot_streams_enhanced(
    indices= [10, 22],
    channels_per_stream=[[0], [0]],  # Each stream has 1 channel
    max_duration=9000,  # Adjust as needed
    labels=labels,
    show_markers=True
)
explorer.print_marker_timeline()
# Out:
# ⏰ COMPLETE MARKER TIMELINE
# ...
#     Time | Type            | Block | Trial | Image                | Stream
# --------------------------------------------------------------------------------
#     1.60s | BLOCK_START     | 1     | N/A   | N/A                  | Markers
#     4.55s | TRIAL_START     | 1     | 1     | N/A                  | Markers
#     4.55s | IMAGE           | 1     | 1     | Jail 2.jpg           | Markers
#     4.66s | SPACEBAR        | 1     | 1     | N/A                  | Markers
#     6.19s | SPACEBAR        | 1     | 1     | N/A                  | Markers
#     8.56s | TRIAL_START     | 1     | 2     | N/A                  | Markers
#     8.56s | IMAGE           | 1     | 2     | Street 5.jpg         | Markers
#     9.97s | SPACEBAR        | 1     | 2     | N/A                  | Markers
#    12.56s | TRIAL_START     | 1     | 3     | N/A                  | Markers
#    12.56s | IMAGE           | 1     | 3     | Camping 2.jpg        | Markers
# ...

# %%
# #%%
# # See all available blocks with statistics
# explorer.list_all_block_ids()

# # Print details for block 1
# print("Print detailed markers for block 1")
# explorer.print_marker_timeline(block_id=1)

# # Print details for block 2
# print("Print detailed markers for block 2")
# explorer.print_marker_timeline(block_id=2)

# # See all markers across all blocks
# print("See all markers across all blocks")
# explorer.print_marker_timeline()
# # In your other Python file (e.g., analysis.py)
# from LabRecorder_Viewer import XDFExplorer

# # Create an instance
# explorer = XDFExplorer("./data/TEST_2_Emotibit.xdf")

# # Use the methods
# explorer.list_all_block_ids()
# block_data = explorer.extract_block_data(2)
# explorer.analyze_block_data(block_data)
# explorer.analyze_data_quality()
# explorer.list_streams_by_source_id('MD-V7-0000192')
# explorer.list_streams_by_source_id('MD-V7-0000027')
# explorer.export_stream_info()
# explorer.print_detailed_summary()
# # Create labels with source_id for clarity
# labels = ["MD-V7-0000192 GYRO_Z", "MD-V7-0000027 GYRO_Z"]

# # Plot them
# explorer.plot_streams_enhanced(
#     indices= [3, 12],
#     channels_per_stream=[[0], [0]],  # Each stream has 1 channel
#     max_duration=90,  # Adjust as needed
#     labels=labels,
#     show_markers=True
# )
# explorer.print_marker_timeline()

# #%%
# # See all available blocks with statistics
# explorer.list_all_block_ids()

# # Print details for block 1
# print("Print detailed markers for block 1")
# explorer.print_marker_timeline(block_id=1)

# # Print details for block 2
# print("Print detailed markers for block 2")
# explorer.print_marker_timeline(block_id=2)

# # See all markers across all blocks
# print("See all markers across all blocks")
# explorer.print_marker_timeline()
# Out:
# ⏰ COMPLETE MARKER TIMELINE
# ...
#     Time | Type            | Block | Trial | Image                | Stream
# --------------------------------------------------------------------------------
#     1.60s | BLOCK_START     | 1     | N/A   | N/A                  | Markers
#     4.55s | TRIAL_START     | 1     | 1     | N/A                  | Markers
#     4.55s | IMAGE           | 1     | 1     | Jail 2.jpg           | Markers
#     4.66s | SPACEBAR        | 1     | 1     | N/A                  | Markers
#     6.19s | SPACEBAR        | 1     | 1     | N/A                  | Markers
#     8.56s | TRIAL_START     | 1     | 2     | N/A                  | Markers
#     8.56s | IMAGE           | 1     | 2     | Street 5.jpg         | Markers
#     9.97s | SPACEBAR        | 1     | 2     | N/A                  | Markers
#    12.56s | TRIAL_START     | 1     | 3     | N/A                  | Markers
#    12.56s | IMAGE           | 1     | 3     | Camping 2.jpg        | Markers
# ...

# %% [markdown]
# ## Oct 28rd

# %%
## Oct 27rd
# In your other Python file (e.g., analysis.py)
from LabRecorder_Viewer import XDFExplorer

# Create an instance
explorer = XDFExplorer("./data/VAMPalone.xdf")
# Out:
# Stream 1: Calculated effective sampling rate 326.9026 Hz is different from specified rate 500.0000 Hz.
# Stream 1: Segments and clock-segments differ
# ✅ Loaded XDF file: ./data/VAMPalone.xdf
# 📊 Found 1 streams
# 🕒 Experiment start (t0): 2812.489 s
#
# --- Stream Summary ---
# [0] source_id: RDA 127.0.0.1:51244 	    | BrainVision RDA 	 | type: EEG 	 | channels: 19 	 | Fs: 500.0 Hz 	 | samples: 2260 	 | time: 0.00–4.49s

# %%
# Use the methods
explorer.analyze_data_quality()
# Out:
# 🔍 DATA QUALITY ANALYSIS
# ...
# [0] BrainVision RDA:
#     Duration: 4.49s
#     Completeness: 100.7%
#     Data gaps: 1001
#     Quality: ⚠️ FAIR

# %%
explorer.list_streams_by_source_id('RDA 127.0.0.1:51244')
# explorer.list_streams_by_source_id('MD-V7-0000027')
# explorer.export_stream_info()
# explorer.print_detailed_summary()
# # Create labels with source_id for clarity
# labels = ["MD-V7-0000192 GYRO_Z", "MD-V7-0000027 GYRO_Z"]

# # Plot them
# explorer.plot_streams_enhanced(
#     indices= [3, 12],
#     channels_per_stream=[[0], [0]],  # Each stream has 1 channel
#     max_duration=90,  # Adjust as needed
#     labels=labels,
#     show_markers=True
# )
# explorer.print_marker_timeline()

# #%%
# # See all available blocks with statistics
# explorer.list_all_block_ids()

# # Print details for block 1
# print("Print detailed markers for block 1")
# explorer.print_marker_timeline(block_id=1)

# # Print details for block 2
# print("Print detailed markers for block 2")
# explorer.print_marker_timeline(block_id=2)

# # See all markers across all blocks
# print("See all markers across all blocks")
# explorer.print_marker_timeline()
# # In your other Python file (e.g., analysis.py)
# from LabRecorder_Viewer import XDFExplorer

# # Create an instance
# explorer = XDFExplorer("./data/TEST_2_Emotibit.xdf")

# # Use the methods
# explorer.list_all_block_ids()
# block_data = explorer.extract_block_data(2)
# explorer.analyze_block_data(block_data)
# explorer.analyze_data_quality()
# explorer.list_streams_by_source_id('MD-V7-0000192')
# explorer.list_streams_by_source_id('MD-V7-0000027')
# explorer.export_stream_info()
# explorer.print_detailed_summary()
# # Create labels with source_id for clarity
# labels = ["MD-V7-0000192 GYRO_Z", "MD-V7-0000027 GYRO_Z"]

# # Plot them
# explorer.plot_streams_enhanced(
#     indices= [3, 12],
#     channels_per_stream=[[0], [0]],  # Each stream has 1 channel
#     max_duration=90,  # Adjust as needed
#     labels=labels,
#     show_markers=True
# )
# explorer.print_marker_timeline()

# #%%
# # See all available blocks with statistics
# explorer.list_all_block_ids()

# # Print details for block 1
# print("Print detailed markers for block 1")
# explorer.print_marker_timeline(block_id=1)

# # Print details for block 2
# print("Print detailed markers for block 2")
# explorer.print_marker_timeline(block_id=2)

# # See all markers across all blocks
# print("See all markers across all blocks")
# explorer.print_marker_timeline()
# Out:
# 📡 STREAMS FOR SOURCE ID: RDA 127.0.0.1:51244
# ...
#
# [1] RDA 127.0.0.1:51244
#     [0] BrainVision RDA: EEG (500.0 Hz)

# %% [markdown]
# ## Oct 27rd

# %%
# In your other Python file (e.g., analysis.py)
from LabRecorder_Viewer import XDFExplorer

# Create an instance
explorer = XDFExplorer("./data/TEST_2_Emotibit.xdf")

# Use the methods
explorer.list_all_block_ids()
block_data = explorer.extract_block_data(2)
explorer.analyze_block_data(block_data)
# Out:
# ✅ Loaded XDF file: ./data/TEST_2_Emotibit.xdf
# 📊 Found 39 streams
# 🕒 Experiment start (t0): 350101.777 s
#
# --- Stream Summary ---
# [0] source_id: MD-V7-0000027 	    | SCR_AMP 	 | type: SCRAmplitude 	 | channels: 1 	 | Fs: 0.0 Hz 	 | samples: 0 	 | time: 0.00–0.00s
# [1] source_id: MD-V7-0000027 	    | THERM 	 | type: Thermopile 	 | channels: 1 	 | Fs: 7.5 Hz 	 | samples: 688 	 | time: 0.16–91.75s
# [2] source_id: MD-V7-0000192 	    | ACC_X 	 | type: AccelerometerX 	 | channels: 1 	 | Fs: 25.0 Hz 	 | samples: 2313 	 | time: 0.00–92.32s
# [3] source_id: MD-V7-0000192 	    | GYRO_Z 	 | type: GyroscopeZ 	 | channels: 1 	 | Fs: 25.0 Hz 	 | samples: 2311 	 | time: 0.09–92.32s
# [4] source_id: MD-V7-0000192 	    | MAG_X 	 | type: MagnetometerX 	 | channels: 1 	 | Fs: 25.0 Hz 	 | samples: 2311 	 | time: 0.01–92.25s
# [5] source_id: MD-V7-0000027 	    | HR 	 | type: HeartRate 	 | channels: 1 	 | Fs: 0.0 Hz 	 | samples: 41 	 | time: 8.59–77.76s
# ...

# %%
explorer.analyze_data_quality()
# Out:
# 🔍 DATA QUALITY ANALYSIS
# ...
# [0] SCR_AMP: ❌ EMPTY STREAM
# [1] THERM:
#     Duration: 91.59s
#     Completeness: 100.2%
#     Data gaps: 0
#     Quality: ✅ EXCELLENT
# [2] ACC_X:
#     Duration: 92.32s
#     Completeness: 100.2%
#     Data gaps: 0
#     Quality: ✅ EXCELLENT
# [3] GYRO_Z:
#     Duration: 92.24s
#     Completeness: 100.2%
#     Data gaps: 0
#     Quality: ✅ EXCELLENT
# [4] MAG_X:
#     Duration: 92.24s
#     Completeness: 100.2%
#     Data gaps: 0
#     Quality: ✅ EXCELLENT
# [5] HR:
#     Duration: 69.17s
#     Markers: 41
#     Interval range: 0.292s - 52.108s
#     Avg interval: 1.729s
#     Quality: ✅ EXCELLENT
# [6] THERM:
#     Duration: 92.12s
#     Completeness: 100.2%
#     Data gaps: 0
#     Quality: ✅ EXCELLENT
# [7] SCR_FREQ:
#     Duration: 91.92s
#     Markers: 277
#     Interval range: 0.095s - 0.530s
#     Avg interval: 0.333s
#     Quality: ✅ EXCELLENT
# [8] ACC_Y:
#     Duration: 92.08s
#     Completeness: 101.7%
#     Data gaps: 0
# ...

# %%
explorer.list_streams_by_source_id('MD-V7-0000192')
# Out:
# 📡 STREAMS FOR SOURCE ID: MD-V7-0000192
# ...
#
# [2] MD-V7-0000192
#     [2] ACC_X: AccelerometerX (25.0 Hz)
#     [3] GYRO_Z: GyroscopeZ (25.0 Hz)
#     [4] MAG_X: MagnetometerX (25.0 Hz)
#     [6] THERM: Thermopile (7.5 Hz)
#     [9] PPG_RED: PPGRed (25.0 Hz)
#     [11] SCR_FREQ: SCRFrequency (0.0 Hz)
#     [15] PPG_IR: PPGInfrared (25.0 Hz)
#     [16] TEMP1: Temperature (7.5 Hz)
#     [17] PPG_GRN: PPGGreen (25.0 Hz)
#     [18] MAG_Z: MagnetometerZ (25.0 Hz)
#     [19] MAG_Y: MagnetometerY (25.0 Hz)
#     [21] ACC_Z: AccelerometerZ (25.0 Hz)
#     [23] SCR_RIS: SCRRiseTime (0.0 Hz)
#     [24] SCR_AMP: SCRAmplitude (0.0 Hz)
#     [25] ACC_Y: AccelerometerY (25.0 Hz)
#     [28] HR: HeartRate (0.0 Hz)
#     [30] GYRO_X: GyroscopeX (25.0 Hz)
#     [33] GYRO_Y: GyroscopeY (25.0 Hz)
#     [34] EDA: EDA (15.0 Hz)

# %%
explorer.list_streams_by_source_id('MD-V7-0000027')
# Out:
# 📡 STREAMS FOR SOURCE ID: MD-V7-0000027
# ...
#
# [1] MD-V7-0000027
#     [0] SCR_AMP: SCRAmplitude (0.0 Hz)
#     [1] THERM: Thermopile (7.5 Hz)
#     [5] HR: HeartRate (0.0 Hz)
#     [7] SCR_FREQ: SCRFrequency (0.0 Hz)
#     [8] ACC_Y: AccelerometerY (25.0 Hz)
#     [12] GYRO_Z: GyroscopeZ (25.0 Hz)
#     [13] MAG_Y: MagnetometerY (25.0 Hz)
#     [14] PPG_IR: PPGInfrared (25.0 Hz)
#     [20] ACC_X: AccelerometerX (25.0 Hz)
#     [22] MAG_Z: MagnetometerZ (25.0 Hz)
#     [26] PPG_GRN: PPGGreen (25.0 Hz)
#     [27] MAG_X: MagnetometerX (25.0 Hz)
#     [29] SCR_RIS: SCRRiseTime (0.0 Hz)
#     [31] PPG_RED: PPGRed (25.0 Hz)
#     [32] TEMP1: Temperature (7.5 Hz)
#     [35] GYRO_X: GyroscopeX (25.0 Hz)
#     [36] GYRO_Y: GyroscopeY (25.0 Hz)
#     [37] EDA: EDA (15.0 Hz)
#     [38] ACC_Z: AccelerometerZ (25.0 Hz)

# %%
explorer.export_stream_info()
# Out:
# 📄 Stream analysis exported to: ./devLogs/stream_analysis_39_streams.txt

# %%
explorer.print_detailed_summary()
# Out:
# ...
# 📊 DETAILED STREAM ANALYSIS
# ...
#
# [0] 📡 EMOTIBIT
#     Name: SCR_AMP
#     Source ID: MD-V7-0000027
#     Type: SCRAmplitude
#     Channels: 1
#     Sample Rate: 0.0 Hz
#     Samples: 0
#     Duration: 0.00s
#     Time Range: 0.00s - 0.00s
#
# [1] 📡 EMOTIBIT
#     Name: THERM
#     Source ID: MD-V7-0000027
#     Type: Thermopile
#     Channels: 1
#     Sample Rate: 7.5 Hz
#     Samples: 688
#     Duration: 91.59s
#     Time Range: 0.16s - 91.75s
#     Data Type: float32
#     Value Range: 28.146 - 29.266
#
# [2] 📡 EMOTIBIT
#     Name: ACC_X
#     Source ID: MD-V7-0000192
#     Type: AccelerometerX
#     Channels: 1
#     Sample Rate: 25.0 Hz
#     Samples: 2,313
#     Duration: 92.32s
#     Time Range: 0.00s - 92.32s
#     Data Type: float32
#     Value Range: -0.581 - 0.872
#
# [3] 📡 EMOTIBIT
#     Name: GYRO_Z
#     Source ID: MD-V7-0000192
#     Type: GyroscopeZ
#     Channels: 1
#     Sample Rate: 25.0 Hz
#     Samples: 2,311
#     Duration: 92.24s
#     Time Range: 0.09s - 92.32s
# ...

# %%
# Create labels with source_id for clarity
labels = ["MD-V7-0000192 GYRO_Z", "MD-V7-0000027 GYRO_Z"]

# Plot them
explorer.plot_streams_enhanced(
    indices= [3, 12],
    channels_per_stream=[[0], [0]],  # Each stream has 1 channel
    max_duration=90,  # Adjust as needed
    labels=labels,
    show_markers=True
)
# Out:
# /Users/franckporteous/Documents/MindHive/EmotiBit NYU Validation Study/evs-experimentalSoftware/LabRecorder_Viewer.py:450: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /Users/franckporteous/miniforge3/envs/pyStable/lib/python3.11/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
explorer.print_marker_timeline()
# Out:
# ⏰ COMPLETE MARKER TIMELINE
# ...
#     Time | Type            | Block | Trial | Image                | Stream
# --------------------------------------------------------------------------------
#     2.40s | BLOCK_START     | 1     | N/A   | N/A                  | Markers
#     5.20s | TRIAL_START     | 1     | 1     | N/A                  | Markers
#     5.20s | IMAGE           | 1     | 1     | Pinecone 3.jpg       | Markers
#     5.31s | SPACEBAR        | 1     | 1     | N/A                  | Markers
#     7.09s | SPACEBAR        | 1     | 1     | N/A                  | Markers
#     9.21s | TRIAL_START     | 1     | 2     | N/A                  | Markers
#     9.21s | IMAGE           | 1     | 2     | Galaxy 1.jpg         | Markers
#    10.20s | SPACEBAR        | 1     | 2     | N/A                  | Markers
#    16.24s | TRIAL_START     | 1     | 3     | N/A                  | Markers
#    16.24s | IMAGE           | 1     | 3     | Gun 1.jpg            | Markers
# ...

# %%
#%%
# See all available blocks with statistics
explorer.list_all_block_ids()

# Print details for block 1
print("Print detailed markers for block 1")
explorer.print_marker_timeline(block_id=1)

# Print details for block 2
print("Print detailed markers for block 2")
explorer.print_marker_timeline(block_id=2)

# See all markers across all blocks
print("See all markers across all blocks")
explorer.print_marker_timeline()
# Out:
# 🔍 AVAILABLE BLOCK IDs
# ...
# Found block IDs: [1, 2, 3]
# Total blocks: 3
#
# 📊 Block Statistics:
# ----------------------------------------
# Block 1: 11 markers, 3 trials
#   Marker types: BLOCK_START, IMAGE, SPACEBAR, TRIAL_START
# Block 2: 11 markers, 3 trials
#   Marker types: BLOCK_START, IMAGE, SPACEBAR, TRIAL_START
# Block 3: 11 markers, 3 trials
#   Marker types: BLOCK_START, IMAGE, SPACEBAR, TRIAL_START
# Print detailed markers for block 1
#
# ⏰ MARKER TIMELINE FOR BLOCK 1
# ...
#     Time | Type            | Block | Trial | Image                | Stream
# --------------------------------------------------------------------------------
#     2.40s | BLOCK_START     | 1     | N/A   | N/A                  | Markers
#     5.20s | TRIAL_START     | 1     | 1     | N/A                  | Markers
#     5.20s | IMAGE           | 1     | 1     | Pinecone 3.jpg       | Markers
#     5.31s | SPACEBAR        | 1     | 1     | N/A                  | Markers
# ...

# %%
# In your other Python file (e.g., analysis.py)
from LabRecorder_Viewer import XDFExplorer

# Create an instance
explorer = XDFExplorer("./data/TEST_2_Emotibit.xdf")

# Use the methods
explorer.list_all_block_ids()
block_data = explorer.extract_block_data(2)
explorer.analyze_block_data(block_data)
# Out:
# ✅ Loaded XDF file: ./data/TEST_2_Emotibit.xdf
# 📊 Found 39 streams
# 🕒 Experiment start (t0): 350101.777 s
#
# --- Stream Summary ---
# [0] source_id: MD-V7-0000027 	    | SCR_AMP 	 | type: SCRAmplitude 	 | channels: 1 	 | Fs: 0.0 Hz 	 | samples: 0 	 | time: 0.00–0.00s
# [1] source_id: MD-V7-0000027 	    | THERM 	 | type: Thermopile 	 | channels: 1 	 | Fs: 7.5 Hz 	 | samples: 688 	 | time: 0.16–91.75s
# [2] source_id: MD-V7-0000192 	    | ACC_X 	 | type: AccelerometerX 	 | channels: 1 	 | Fs: 25.0 Hz 	 | samples: 2313 	 | time: 0.00–92.32s
# [3] source_id: MD-V7-0000192 	    | GYRO_Z 	 | type: GyroscopeZ 	 | channels: 1 	 | Fs: 25.0 Hz 	 | samples: 2311 	 | time: 0.09–92.32s
# [4] source_id: MD-V7-0000192 	    | MAG_X 	 | type: MagnetometerX 	 | channels: 1 	 | Fs: 25.0 Hz 	 | samples: 2311 	 | time: 0.01–92.25s
# [5] source_id: MD-V7-0000027 	    | HR 	 | type: HeartRate 	 | channels: 1 	 | Fs: 0.0 Hz 	 | samples: 41 	 | time: 8.59–77.76s
# ...

# %%
explorer.analyze_data_quality()
# Out:
# 🔍 DATA QUALITY ANALYSIS
# ...
# [0] SCR_AMP: ❌ EMPTY STREAM
# [1] THERM:
#     Duration: 91.59s
#     Completeness: 100.2%
#     Data gaps: 0
#     Quality: ✅ EXCELLENT
# [2] ACC_X:
#     Duration: 92.32s
#     Completeness: 100.2%
#     Data gaps: 0
#     Quality: ✅ EXCELLENT
# [3] GYRO_Z:
#     Duration: 92.24s
#     Completeness: 100.2%
#     Data gaps: 0
#     Quality: ✅ EXCELLENT
# [4] MAG_X:
#     Duration: 92.24s
#     Completeness: 100.2%
#     Data gaps: 0
#     Quality: ✅ EXCELLENT
# [5] HR:
#     Duration: 69.17s
#     Markers: 41
#     Interval range: 0.292s - 52.108s
#     Avg interval: 1.729s
#     Quality: ✅ EXCELLENT
# [6] THERM:
#     Duration: 92.12s
#     Completeness: 100.2%
#     Data gaps: 0
#     Quality: ✅ EXCELLENT
# [7] SCR_FREQ:
#     Duration: 91.92s
#     Markers: 277
#     Interval range: 0.095s - 0.530s
#     Avg interval: 0.333s
#     Quality: ✅ EXCELLENT
# [8] ACC_Y:
#     Duration: 92.08s
#     Completeness: 101.7%
#     Data gaps: 0
# ...

# %%
explorer.list_streams_by_source_id('MD-V7-0000192')
# Out:
# 📡 STREAMS FOR SOURCE ID: MD-V7-0000192
# ...
#
# [2] MD-V7-0000192
#     [2] ACC_X: AccelerometerX (25.0 Hz)
#     [3] GYRO_Z: GyroscopeZ (25.0 Hz)
#     [4] MAG_X: MagnetometerX (25.0 Hz)
#     [6] THERM: Thermopile (7.5 Hz)
#     [9] PPG_RED: PPGRed (25.0 Hz)
#     [11] SCR_FREQ: SCRFrequency (0.0 Hz)
#     [15] PPG_IR: PPGInfrared (25.0 Hz)
#     [16] TEMP1: Temperature (7.5 Hz)
#     [17] PPG_GRN: PPGGreen (25.0 Hz)
#     [18] MAG_Z: MagnetometerZ (25.0 Hz)
#     [19] MAG_Y: MagnetometerY (25.0 Hz)
#     [21] ACC_Z: AccelerometerZ (25.0 Hz)
#     [23] SCR_RIS: SCRRiseTime (0.0 Hz)
#     [24] SCR_AMP: SCRAmplitude (0.0 Hz)
#     [25] ACC_Y: AccelerometerY (25.0 Hz)
#     [28] HR: HeartRate (0.0 Hz)
#     [30] GYRO_X: GyroscopeX (25.0 Hz)
#     [33] GYRO_Y: GyroscopeY (25.0 Hz)
#     [34] EDA: EDA (15.0 Hz)

# %%
explorer.list_streams_by_source_id('MD-V7-0000027')
# Out:
# 📡 STREAMS FOR SOURCE ID: MD-V7-0000027
# ...
#
# [1] MD-V7-0000027
#     [0] SCR_AMP: SCRAmplitude (0.0 Hz)
#     [1] THERM: Thermopile (7.5 Hz)
#     [5] HR: HeartRate (0.0 Hz)
#     [7] SCR_FREQ: SCRFrequency (0.0 Hz)
#     [8] ACC_Y: AccelerometerY (25.0 Hz)
#     [12] GYRO_Z: GyroscopeZ (25.0 Hz)
#     [13] MAG_Y: MagnetometerY (25.0 Hz)
#     [14] PPG_IR: PPGInfrared (25.0 Hz)
#     [20] ACC_X: AccelerometerX (25.0 Hz)
#     [22] MAG_Z: MagnetometerZ (25.0 Hz)
#     [26] PPG_GRN: PPGGreen (25.0 Hz)
#     [27] MAG_X: MagnetometerX (25.0 Hz)
#     [29] SCR_RIS: SCRRiseTime (0.0 Hz)
#     [31] PPG_RED: PPGRed (25.0 Hz)
#     [32] TEMP1: Temperature (7.5 Hz)
#     [35] GYRO_X: GyroscopeX (25.0 Hz)
#     [36] GYRO_Y: GyroscopeY (25.0 Hz)
#     [37] EDA: EDA (15.0 Hz)
#     [38] ACC_Z: AccelerometerZ (25.0 Hz)

# %%
explorer.export_stream_info()
# Out:
# 📄 Stream analysis exported to: ./devLogs/stream_analysis_39_streams.txt

# %%
explorer.print_detailed_summary()
# Out:
# ...
# 📊 DETAILED STREAM ANALYSIS
# ...
#
# [0] 📡 EMOTIBIT
#     Name: SCR_AMP
#     Source ID: MD-V7-0000027
#     Type: SCRAmplitude
#     Channels: 1
#     Sample Rate: 0.0 Hz
#     Samples: 0
#     Duration: 0.00s
#     Time Range: 0.00s - 0.00s
#
# [1] 📡 EMOTIBIT
#     Name: THERM
#     Source ID: MD-V7-0000027
#     Type: Thermopile
#     Channels: 1
#     Sample Rate: 7.5 Hz
#     Samples: 688
#     Duration: 91.59s
#     Time Range: 0.16s - 91.75s
#     Data Type: float32
#     Value Range: 28.146 - 29.266
#
# [2] 📡 EMOTIBIT
#     Name: ACC_X
#     Source ID: MD-V7-0000192
#     Type: AccelerometerX
#     Channels: 1
#     Sample Rate: 25.0 Hz
#     Samples: 2,313
#     Duration: 92.32s
#     Time Range: 0.00s - 92.32s
#     Data Type: float32
#     Value Range: -0.581 - 0.872
#
# [3] 📡 EMOTIBIT
#     Name: GYRO_Z
#     Source ID: MD-V7-0000192
#     Type: GyroscopeZ
#     Channels: 1
#     Sample Rate: 25.0 Hz
#     Samples: 2,311
#     Duration: 92.24s
#     Time Range: 0.09s - 92.32s
# ...

# %%
# Create labels with source_id for clarity
labels = ["MD-V7-0000192 GYRO_Z", "MD-V7-0000027 GYRO_Z"]

# Plot them
explorer.plot_streams_enhanced(
    indices= [3, 12],
    channels_per_stream=[[0], [0]],  # Each stream has 1 channel
    max_duration=90,  # Adjust as needed
    labels=labels,
    show_markers=True
)
# Out:
# /Users/franckporteous/Documents/MindHive/EmotiBit NYU Validation Study/evs-experimentalSoftware/LabRecorder_Viewer.py:450: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /Users/franckporteous/miniforge3/envs/pyStable/lib/python3.11/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
explorer.print_marker_timeline()
# Out:
# ⏰ COMPLETE MARKER TIMELINE
# ...
#     Time | Type            | Block | Trial | Image                | Stream
# --------------------------------------------------------------------------------
#     2.40s | BLOCK_START     | 1     | N/A   | N/A                  | Markers
#     5.20s | TRIAL_START     | 1     | 1     | N/A                  | Markers
#     5.20s | IMAGE           | 1     | 1     | Pinecone 3.jpg       | Markers
#     5.31s | SPACEBAR        | 1     | 1     | N/A                  | Markers
#     7.09s | SPACEBAR        | 1     | 1     | N/A                  | Markers
#     9.21s | TRIAL_START     | 1     | 2     | N/A                  | Markers
#     9.21s | IMAGE           | 1     | 2     | Galaxy 1.jpg         | Markers
#    10.20s | SPACEBAR        | 1     | 2     | N/A                  | Markers
#    16.24s | TRIAL_START     | 1     | 3     | N/A                  | Markers
#    16.24s | IMAGE           | 1     | 3     | Gun 1.jpg            | Markers
# ...

# %%
#%%
# See all available blocks with statistics
explorer.list_all_block_ids()

# Print details for block 1
print("Print detailed markers for block 1")
explorer.print_marker_timeline(block_id=1)

# Print details for block 2
print("Print detailed markers for block 2")
explorer.print_marker_timeline(block_id=2)

# See all markers across all blocks
print("See all markers across all blocks")
explorer.print_marker_timeline()
# Out:
# 🔍 AVAILABLE BLOCK IDs
# ...
# Found block IDs: [1, 2, 3]
# Total blocks: 3
#
# 📊 Block Statistics:
# ----------------------------------------
# Block 1: 11 markers, 3 trials
#   Marker types: BLOCK_START, IMAGE, SPACEBAR, TRIAL_START
# Block 2: 11 markers, 3 trials
#   Marker types: BLOCK_START, IMAGE, SPACEBAR, TRIAL_START
# Block 3: 11 markers, 3 trials
#   Marker types: BLOCK_START, IMAGE, SPACEBAR, TRIAL_START
# Print detailed markers for block 1
#
# ⏰ MARKER TIMELINE FOR BLOCK 1
# ...
#     Time | Type            | Block | Trial | Image                | Stream
# --------------------------------------------------------------------------------
#     2.40s | BLOCK_START     | 1     | N/A   | N/A                  | Markers
#     5.20s | TRIAL_START     | 1     | 1     | N/A                  | Markers
#     5.20s | IMAGE           | 1     | 1     | Pinecone 3.jpg       | Markers
#     5.31s | SPACEBAR        | 1     | 1     | N/A                  | Markers
# ...

# %%
# In your other Python file (e.g., analysis.py)
from LabRecorder_Viewer import XDFExplorer

# Create an instance
explorer = XDFExplorer("./data/TEST_2_Emotibit.xdf")

# Use the methods
explorer.list_all_block_ids()
block_data = explorer.extract_block_data(2)
explorer.analyze_block_data(block_data)
# Out:
# ✅ Loaded XDF file: ./data/TEST_2_Emotibit.xdf
# 📊 Found 39 streams
# 🕒 Experiment start (t0): 350101.777 s
#
# --- Stream Summary ---
# [0] source_id: MD-V7-0000027 	    | SCR_AMP 	 | type: SCRAmplitude 	 | channels: 1 	 | Fs: 0.0 Hz 	 | samples: 0 	 | time: 0.00–0.00s
# [1] source_id: MD-V7-0000027 	    | THERM 	 | type: Thermopile 	 | channels: 1 	 | Fs: 7.5 Hz 	 | samples: 688 	 | time: 0.16–91.75s
# [2] source_id: MD-V7-0000192 	    | ACC_X 	 | type: AccelerometerX 	 | channels: 1 	 | Fs: 25.0 Hz 	 | samples: 2313 	 | time: 0.00–92.32s
# [3] source_id: MD-V7-0000192 	    | GYRO_Z 	 | type: GyroscopeZ 	 | channels: 1 	 | Fs: 25.0 Hz 	 | samples: 2311 	 | time: 0.09–92.32s
# [4] source_id: MD-V7-0000192 	    | MAG_X 	 | type: MagnetometerX 	 | channels: 1 	 | Fs: 25.0 Hz 	 | samples: 2311 	 | time: 0.01–92.25s
# [5] source_id: MD-V7-0000027 	    | HR 	 | type: HeartRate 	 | channels: 1 	 | Fs: 0.0 Hz 	 | samples: 41 	 | time: 8.59–77.76s
# ...

# %%
explorer.analyze_data_quality()
# Out:
# 🔍 DATA QUALITY ANALYSIS
# ...
# [0] SCR_AMP: ❌ EMPTY STREAM
# [1] THERM:
#     Duration: 91.59s
#     Completeness: 100.2%
#     Data gaps: 0
#     Quality: ✅ EXCELLENT
# [2] ACC_X:
#     Duration: 92.32s
#     Completeness: 100.2%
#     Data gaps: 0
#     Quality: ✅ EXCELLENT
# [3] GYRO_Z:
#     Duration: 92.24s
#     Completeness: 100.2%
#     Data gaps: 0
#     Quality: ✅ EXCELLENT
# [4] MAG_X:
#     Duration: 92.24s
#     Completeness: 100.2%
#     Data gaps: 0
#     Quality: ✅ EXCELLENT
# [5] HR:
#     Duration: 69.17s
#     Markers: 41
#     Interval range: 0.292s - 52.108s
#     Avg interval: 1.729s
#     Quality: ✅ EXCELLENT
# [6] THERM:
#     Duration: 92.12s
#     Completeness: 100.2%
#     Data gaps: 0
#     Quality: ✅ EXCELLENT
# [7] SCR_FREQ:
#     Duration: 91.92s
#     Markers: 277
#     Interval range: 0.095s - 0.530s
#     Avg interval: 0.333s
#     Quality: ✅ EXCELLENT
# [8] ACC_Y:
#     Duration: 92.08s
#     Completeness: 101.7%
#     Data gaps: 0
# ...

# %%
explorer.list_streams_by_source_id('MD-V7-0000192')
# Out:
# 📡 STREAMS FOR SOURCE ID: MD-V7-0000192
# ...
#
# [2] MD-V7-0000192
#     [2] ACC_X: AccelerometerX (25.0 Hz)
#     [3] GYRO_Z: GyroscopeZ (25.0 Hz)
#     [4] MAG_X: MagnetometerX (25.0 Hz)
#     [6] THERM: Thermopile (7.5 Hz)
#     [9] PPG_RED: PPGRed (25.0 Hz)
#     [11] SCR_FREQ: SCRFrequency (0.0 Hz)
#     [15] PPG_IR: PPGInfrared (25.0 Hz)
#     [16] TEMP1: Temperature (7.5 Hz)
#     [17] PPG_GRN: PPGGreen (25.0 Hz)
#     [18] MAG_Z: MagnetometerZ (25.0 Hz)
#     [19] MAG_Y: MagnetometerY (25.0 Hz)
#     [21] ACC_Z: AccelerometerZ (25.0 Hz)
#     [23] SCR_RIS: SCRRiseTime (0.0 Hz)
#     [24] SCR_AMP: SCRAmplitude (0.0 Hz)
#     [25] ACC_Y: AccelerometerY (25.0 Hz)
#     [28] HR: HeartRate (0.0 Hz)
#     [30] GYRO_X: GyroscopeX (25.0 Hz)
#     [33] GYRO_Y: GyroscopeY (25.0 Hz)
#     [34] EDA: EDA (15.0 Hz)

# %%
explorer.list_streams_by_source_id('MD-V7-0000027')
# Out:
# 📡 STREAMS FOR SOURCE ID: MD-V7-0000027
# ...
#
# [1] MD-V7-0000027
#     [0] SCR_AMP: SCRAmplitude (0.0 Hz)
#     [1] THERM: Thermopile (7.5 Hz)
#     [5] HR: HeartRate (0.0 Hz)
#     [7] SCR_FREQ: SCRFrequency (0.0 Hz)
#     [8] ACC_Y: AccelerometerY (25.0 Hz)
#     [12] GYRO_Z: GyroscopeZ (25.0 Hz)
#     [13] MAG_Y: MagnetometerY (25.0 Hz)
#     [14] PPG_IR: PPGInfrared (25.0 Hz)
#     [20] ACC_X: AccelerometerX (25.0 Hz)
#     [22] MAG_Z: MagnetometerZ (25.0 Hz)
#     [26] PPG_GRN: PPGGreen (25.0 Hz)
#     [27] MAG_X: MagnetometerX (25.0 Hz)
#     [29] SCR_RIS: SCRRiseTime (0.0 Hz)
#     [31] PPG_RED: PPGRed (25.0 Hz)
#     [32] TEMP1: Temperature (7.5 Hz)
#     [35] GYRO_X: GyroscopeX (25.0 Hz)
#     [36] GYRO_Y: GyroscopeY (25.0 Hz)
#     [37] EDA: EDA (15.0 Hz)
#     [38] ACC_Z: AccelerometerZ (25.0 Hz)

# %%
explorer.export_stream_info()
# Out:
# 📄 Stream analysis exported to: ./devLogs/stream_analysis_39_streams.txt

# %%
explorer.print_detailed_summary()
# Out:
# ...
# 📊 DETAILED STREAM ANALYSIS
# ...
#
# [0] 📡 EMOTIBIT
#     Name: SCR_AMP
#     Source ID: MD-V7-0000027
#     Type: SCRAmplitude
#     Channels: 1
#     Sample Rate: 0.0 Hz
#     Samples: 0
#     Duration: 0.00s
#     Time Range: 0.00s - 0.00s
#
# [1] 📡 EMOTIBIT
#     Name: THERM
#     Source ID: MD-V7-0000027
#     Type: Thermopile
#     Channels: 1
#     Sample Rate: 7.5 Hz
#     Samples: 688
#     Duration: 91.59s
#     Time Range: 0.16s - 91.75s
#     Data Type: float32
#     Value Range: 28.146 - 29.266
#
# [2] 📡 EMOTIBIT
#     Name: ACC_X
#     Source ID: MD-V7-0000192
#     Type: AccelerometerX
#     Channels: 1
#     Sample Rate: 25.0 Hz
#     Samples: 2,313
#     Duration: 92.32s
#     Time Range: 0.00s - 92.32s
#     Data Type: float32
#     Value Range: -0.581 - 0.872
#
# [3] 📡 EMOTIBIT
#     Name: GYRO_Z
#     Source ID: MD-V7-0000192
#     Type: GyroscopeZ
#     Channels: 1
#     Sample Rate: 25.0 Hz
#     Samples: 2,311
#     Duration: 92.24s
#     Time Range: 0.09s - 92.32s
# ...

# %%
# Create labels with source_id for clarity
labels = ["MD-V7-0000192 GYRO_Z", "MD-V7-0000027 GYRO_Z"]

# Plot them
explorer.plot_streams_enhanced(
    indices= [3, 12],
    channels_per_stream=[[0], [0]],  # Each stream has 1 channel
    max_duration=90,  # Adjust as needed
    labels=labels,
    show_markers=True
)
# Out:
# /Users/franckporteous/Documents/MindHive/EmotiBit NYU Validation Study/evs-experimentalSoftware/LabRecorder_Viewer.py:450: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /Users/franckporteous/miniforge3/envs/pyStable/lib/python3.11/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
explorer.print_marker_timeline()
# Out:
# ⏰ COMPLETE MARKER TIMELINE
# ...
#     Time | Type            | Block | Trial | Image                | Stream
# --------------------------------------------------------------------------------
#     2.40s | BLOCK_START     | 1     | N/A   | N/A                  | Markers
#     5.20s | TRIAL_START     | 1     | 1     | N/A                  | Markers
#     5.20s | IMAGE           | 1     | 1     | Pinecone 3.jpg       | Markers
#     5.31s | SPACEBAR        | 1     | 1     | N/A                  | Markers
#     7.09s | SPACEBAR        | 1     | 1     | N/A                  | Markers
#     9.21s | TRIAL_START     | 1     | 2     | N/A                  | Markers
#     9.21s | IMAGE           | 1     | 2     | Galaxy 1.jpg         | Markers
#    10.20s | SPACEBAR        | 1     | 2     | N/A                  | Markers
#    16.24s | TRIAL_START     | 1     | 3     | N/A                  | Markers
#    16.24s | IMAGE           | 1     | 3     | Gun 1.jpg            | Markers
# ...

# %%
#%%
# See all available blocks with statistics
explorer.list_all_block_ids()

# Print details for block 1
print("Print detailed markers for block 1")
explorer.print_marker_timeline(block_id=1)

# Print details for block 2
print("Print detailed markers for block 2")
explorer.print_marker_timeline(block_id=2)

# See all markers across all blocks
print("See all markers across all blocks")
explorer.print_marker_timeline()
# Out:
# 🔍 AVAILABLE BLOCK IDs
# ...
# Found block IDs: [1, 2, 3]
# Total blocks: 3
#
# 📊 Block Statistics:
# ----------------------------------------
# Block 1: 11 markers, 3 trials
#   Marker types: BLOCK_START, IMAGE, SPACEBAR, TRIAL_START
# Block 2: 11 markers, 3 trials
#   Marker types: BLOCK_START, IMAGE, SPACEBAR, TRIAL_START
# Block 3: 11 markers, 3 trials
#   Marker types: BLOCK_START, IMAGE, SPACEBAR, TRIAL_START
# Print detailed markers for block 1
#
# ⏰ MARKER TIMELINE FOR BLOCK 1
# ...
#     Time | Type            | Block | Trial | Image                | Stream
# --------------------------------------------------------------------------------
#     2.40s | BLOCK_START     | 1     | N/A   | N/A                  | Markers
#     5.20s | TRIAL_START     | 1     | 1     | N/A                  | Markers
#     5.20s | IMAGE           | 1     | 1     | Pinecone 3.jpg       | Markers
#     5.31s | SPACEBAR        | 1     | 1     | N/A                  | Markers
# ...

# %%
# In your other Python file (e.g., analysis.py)
from LabRecorder_Viewer import XDFExplorer

# Create an instance
explorer = XDFExplorer("./data/TEST_2_Emotibit.xdf")

# Use the methods
explorer.list_all_block_ids()
block_data = explorer.extract_block_data(2)
explorer.analyze_block_data(block_data)
# Out:
# ✅ Loaded XDF file: ./data/TEST_2_Emotibit.xdf
# 📊 Found 39 streams
# 🕒 Experiment start (t0): 350101.777 s
#
# --- Stream Summary ---
# [0] source_id: MD-V7-0000027 	    | SCR_AMP 	 | type: SCRAmplitude 	 | channels: 1 	 | Fs: 0.0 Hz 	 | samples: 0 	 | time: 0.00–0.00s
# [1] source_id: MD-V7-0000027 	    | THERM 	 | type: Thermopile 	 | channels: 1 	 | Fs: 7.5 Hz 	 | samples: 688 	 | time: 0.16–91.75s
# [2] source_id: MD-V7-0000192 	    | ACC_X 	 | type: AccelerometerX 	 | channels: 1 	 | Fs: 25.0 Hz 	 | samples: 2313 	 | time: 0.00–92.32s
# [3] source_id: MD-V7-0000192 	    | GYRO_Z 	 | type: GyroscopeZ 	 | channels: 1 	 | Fs: 25.0 Hz 	 | samples: 2311 	 | time: 0.09–92.32s
# [4] source_id: MD-V7-0000192 	    | MAG_X 	 | type: MagnetometerX 	 | channels: 1 	 | Fs: 25.0 Hz 	 | samples: 2311 	 | time: 0.01–92.25s
# [5] source_id: MD-V7-0000027 	    | HR 	 | type: HeartRate 	 | channels: 1 	 | Fs: 0.0 Hz 	 | samples: 41 	 | time: 8.59–77.76s
# ...

# %%
explorer.analyze_data_quality()
# Out:
# 🔍 DATA QUALITY ANALYSIS
# ...
# [0] SCR_AMP: ❌ EMPTY STREAM
# [1] THERM:
#     Duration: 91.59s
#     Completeness: 100.2%
#     Data gaps: 0
#     Quality: ✅ EXCELLENT
# [2] ACC_X:
#     Duration: 92.32s
#     Completeness: 100.2%
#     Data gaps: 0
#     Quality: ✅ EXCELLENT
# [3] GYRO_Z:
#     Duration: 92.24s
#     Completeness: 100.2%
#     Data gaps: 0
#     Quality: ✅ EXCELLENT
# [4] MAG_X:
#     Duration: 92.24s
#     Completeness: 100.2%
#     Data gaps: 0
#     Quality: ✅ EXCELLENT
# [5] HR:
#     Duration: 69.17s
#     Markers: 41
#     Interval range: 0.292s - 52.108s
#     Avg interval: 1.729s
#     Quality: ✅ EXCELLENT
# [6] THERM:
#     Duration: 92.12s
#     Completeness: 100.2%
#     Data gaps: 0
#     Quality: ✅ EXCELLENT
# [7] SCR_FREQ:
#     Duration: 91.92s
#     Markers: 277
#     Interval range: 0.095s - 0.530s
#     Avg interval: 0.333s
#     Quality: ✅ EXCELLENT
# [8] ACC_Y:
#     Duration: 92.08s
#     Completeness: 101.7%
#     Data gaps: 0
# ...

# %%
explorer.list_streams_by_source_id('MD-V7-0000192')
# Out:
# 📡 STREAMS FOR SOURCE ID: MD-V7-0000192
# ...
#
# [2] MD-V7-0000192
#     [2] ACC_X: AccelerometerX (25.0 Hz)
#     [3] GYRO_Z: GyroscopeZ (25.0 Hz)
#     [4] MAG_X: MagnetometerX (25.0 Hz)
#     [6] THERM: Thermopile (7.5 Hz)
#     [9] PPG_RED: PPGRed (25.0 Hz)
#     [11] SCR_FREQ: SCRFrequency (0.0 Hz)
#     [15] PPG_IR: PPGInfrared (25.0 Hz)
#     [16] TEMP1: Temperature (7.5 Hz)
#     [17] PPG_GRN: PPGGreen (25.0 Hz)
#     [18] MAG_Z: MagnetometerZ (25.0 Hz)
#     [19] MAG_Y: MagnetometerY (25.0 Hz)
#     [21] ACC_Z: AccelerometerZ (25.0 Hz)
#     [23] SCR_RIS: SCRRiseTime (0.0 Hz)
#     [24] SCR_AMP: SCRAmplitude (0.0 Hz)
#     [25] ACC_Y: AccelerometerY (25.0 Hz)
#     [28] HR: HeartRate (0.0 Hz)
#     [30] GYRO_X: GyroscopeX (25.0 Hz)
#     [33] GYRO_Y: GyroscopeY (25.0 Hz)
#     [34] EDA: EDA (15.0 Hz)

# %%
explorer.list_streams_by_source_id('MD-V7-0000027')
# Out:
# 📡 STREAMS FOR SOURCE ID: MD-V7-0000027
# ...
#
# [1] MD-V7-0000027
#     [0] SCR_AMP: SCRAmplitude (0.0 Hz)
#     [1] THERM: Thermopile (7.5 Hz)
#     [5] HR: HeartRate (0.0 Hz)
#     [7] SCR_FREQ: SCRFrequency (0.0 Hz)
#     [8] ACC_Y: AccelerometerY (25.0 Hz)
#     [12] GYRO_Z: GyroscopeZ (25.0 Hz)
#     [13] MAG_Y: MagnetometerY (25.0 Hz)
#     [14] PPG_IR: PPGInfrared (25.0 Hz)
#     [20] ACC_X: AccelerometerX (25.0 Hz)
#     [22] MAG_Z: MagnetometerZ (25.0 Hz)
#     [26] PPG_GRN: PPGGreen (25.0 Hz)
#     [27] MAG_X: MagnetometerX (25.0 Hz)
#     [29] SCR_RIS: SCRRiseTime (0.0 Hz)
#     [31] PPG_RED: PPGRed (25.0 Hz)
#     [32] TEMP1: Temperature (7.5 Hz)
#     [35] GYRO_X: GyroscopeX (25.0 Hz)
#     [36] GYRO_Y: GyroscopeY (25.0 Hz)
#     [37] EDA: EDA (15.0 Hz)
#     [38] ACC_Z: AccelerometerZ (25.0 Hz)

# %%
explorer.export_stream_info()
# Out:
# 📄 Stream analysis exported to: ./devLogs/stream_analysis_39_streams.txt

# %%
explorer.print_detailed_summary()
# Out:
# ...
# 📊 DETAILED STREAM ANALYSIS
# ...
#
# [0] 📡 EMOTIBIT
#     Name: SCR_AMP
#     Source ID: MD-V7-0000027
#     Type: SCRAmplitude
#     Channels: 1
#     Sample Rate: 0.0 Hz
#     Samples: 0
#     Duration: 0.00s
#     Time Range: 0.00s - 0.00s
#
# [1] 📡 EMOTIBIT
#     Name: THERM
#     Source ID: MD-V7-0000027
#     Type: Thermopile
#     Channels: 1
#     Sample Rate: 7.5 Hz
#     Samples: 688
#     Duration: 91.59s
#     Time Range: 0.16s - 91.75s
#     Data Type: float32
#     Value Range: 28.146 - 29.266
#
# [2] 📡 EMOTIBIT
#     Name: ACC_X
#     Source ID: MD-V7-0000192
#     Type: AccelerometerX
#     Channels: 1
#     Sample Rate: 25.0 Hz
#     Samples: 2,313
#     Duration: 92.32s
#     Time Range: 0.00s - 92.32s
#     Data Type: float32
#     Value Range: -0.581 - 0.872
#
# [3] 📡 EMOTIBIT
#     Name: GYRO_Z
#     Source ID: MD-V7-0000192
#     Type: GyroscopeZ
#     Channels: 1
#     Sample Rate: 25.0 Hz
#     Samples: 2,311
#     Duration: 92.24s
#     Time Range: 0.09s - 92.32s
# ...

# %%
# Create labels with source_id for clarity
labels = ["MD-V7-0000192 GYRO_Z", "MD-V7-0000027 GYRO_Z"]

# Plot them
explorer.plot_streams_enhanced(
    indices= [3, 12],
    channels_per_stream=[[0], [0]],  # Each stream has 1 channel
    max_duration=90,  # Adjust as needed
    labels=labels,
    show_markers=True
)
# Out:
# /Users/franckporteous/Documents/MindHive/EmotiBit NYU Validation Study/evs-experimentalSoftware/LabRecorder_Viewer.py:450: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /Users/franckporteous/miniforge3/envs/pyStable/lib/python3.11/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
explorer.print_marker_timeline()
# Out:
# ⏰ COMPLETE MARKER TIMELINE
# ...
#     Time | Type            | Block | Trial | Image                | Stream
# --------------------------------------------------------------------------------
#     2.40s | BLOCK_START     | 1     | N/A   | N/A                  | Markers
#     5.20s | TRIAL_START     | 1     | 1     | N/A                  | Markers
#     5.20s | IMAGE           | 1     | 1     | Pinecone 3.jpg       | Markers
#     5.31s | SPACEBAR        | 1     | 1     | N/A                  | Markers
#     7.09s | SPACEBAR        | 1     | 1     | N/A                  | Markers
#     9.21s | TRIAL_START     | 1     | 2     | N/A                  | Markers
#     9.21s | IMAGE           | 1     | 2     | Galaxy 1.jpg         | Markers
#    10.20s | SPACEBAR        | 1     | 2     | N/A                  | Markers
#    16.24s | TRIAL_START     | 1     | 3     | N/A                  | Markers
#    16.24s | IMAGE           | 1     | 3     | Gun 1.jpg            | Markers
# ...

# %%
#%%
# See all available blocks with statistics
explorer.list_all_block_ids()

# Print details for block 1
print("Print detailed markers for block 1")
explorer.print_marker_timeline(block_id=1)

# Print details for block 2
print("Print detailed markers for block 2")
explorer.print_marker_timeline(block_id=2)

# See all markers across all blocks
print("See all markers across all blocks")
explorer.print_marker_timeline()
# Out:
# 🔍 AVAILABLE BLOCK IDs
# ...
# Found block IDs: [1, 2, 3]
# Total blocks: 3
#
# 📊 Block Statistics:
# ----------------------------------------
# Block 1: 11 markers, 3 trials
#   Marker types: BLOCK_START, IMAGE, SPACEBAR, TRIAL_START
# Block 2: 11 markers, 3 trials
#   Marker types: BLOCK_START, IMAGE, SPACEBAR, TRIAL_START
# Block 3: 11 markers, 3 trials
#   Marker types: BLOCK_START, IMAGE, SPACEBAR, TRIAL_START
# Print detailed markers for block 1
#
# ⏰ MARKER TIMELINE FOR BLOCK 1
# ...
#     Time | Type            | Block | Trial | Image                | Stream
# --------------------------------------------------------------------------------
#     2.40s | BLOCK_START     | 1     | N/A   | N/A                  | Markers
#     5.20s | TRIAL_START     | 1     | 1     | N/A                  | Markers
#     5.20s | IMAGE           | 1     | 1     | Pinecone 3.jpg       | Markers
#     5.31s | SPACEBAR        | 1     | 1     | N/A                  | Markers
# ...

# %% [markdown]
# ## Oct 23rd

# %%
# In your other Python file (e.g., analysis.py)
from LabRecorder_Viewer import XDFExplorer

# Create an instance
explorer = XDFExplorer("./data/P0RF.xdf")

# Use the methods
explorer.list_all_block_ids()
block_data = explorer.extract_block_data(2)
explorer.analyze_block_data(block_data)
# Out:
# Stream 2: Segments and clock-segments differ
# ✅ Loaded XDF file: ./data/P0RF.xdf
# 📊 Found 10 streams
# 🕒 Experiment start (t0): 13970.518 s
#
# --- Stream Summary ---
# [0] source_id: LiveAmpSN-054907-0281_STETriggerIn 	    | LiveAmpSN-054907-0281-STETriggerIn 	 | type: Markers 	 | channels: 1 	 | Fs: 0.0 Hz 	 | samples: 0 	 |
# [1] source_id: MD-V7-0000027 	    | MAG_Z 	 | type: MagnetometerZ 	 | channels: 1 	 | Fs: 25.0 Hz 	 | samples: 3343 	 | time: 0.09–131.60s
# [2] source_id: MD-V7-0000027 	    | EDA 	 | type: EDA 	 | channels: 1 	 | Fs: 15.0 Hz 	 | samples: 1974 	 | time: 0.08–131.60s
# [3] source_id: LiveAmpSN-054907-0281 	    | LiveAmpSN-054907-0281 	 | type: EEG 	 | channels: 20 	 | Fs: 500.0 Hz 	 | samples: 65764 	 | time: 0.00–131.53s
# [4] source_id: MD-V7-0000027 	    | MAG_X 	 | type: MagnetometerX 	 | channels: 1 	 | Fs: 25.0 Hz 	 | samples: 3343 	 | time: 0.08–131.60s
# ...

# %%
explorer.analyze_data_quality()
# Out:
# 🔍 DATA QUALITY ANALYSIS
# ...
# [0] LiveAmpSN-054907-0281-STETriggerIn: ❌ EMPTY STREAM
# [1] MAG_Z:
#     Duration: 131.52s
#     Completeness: 101.7%
#     Data gaps: 0
#     Quality: ✅ EXCELLENT
# [2] EDA:
#     Duration: 131.52s
#     Completeness: 100.1%
#     Data gaps: 0
#     Quality: ✅ EXCELLENT
# [3] LiveAmpSN-054907-0281:
#     Duration: 131.53s
#     Completeness: 100.0%
#     Data gaps: 21
#     Quality: ⚠️ FAIR
# [4] MAG_X:
#     Duration: 131.52s
#     Completeness: 101.7%
#     Data gaps: 0
#     Quality: ✅ EXCELLENT
# [5] Markers:
#     Duration: 119.74s
#     Markers: 43
#     Interval range: 0.000s - 18.014s
#     Avg interval: 2.851s
#     Quality: ✅ EXCELLENT
# [6] HR: ❌ EMPTY STREAM
# [7] LiveAmpSN-054907-0281-DeviceTrigger: ❌ EMPTY STREAM
# [8] MAG_Y:
#     Duration: 131.52s
#     Completeness: 101.7%
#     Data gaps: 0
#     Quality: ✅ EXCELLENT
# [9] PPG_RED:
#     Duration: 131.51s
#     Completeness: 99.5%
#     Data gaps: 0
#     Quality: ✅ EXCELLENT

# %%
explorer.export_stream_info()
# Out:
# 📄 Stream analysis exported to: ./devLogs/stream_analysis_10_streams.txt

# %%
explorer.print_detailed_summary()
# Out:
# ...
# 📊 DETAILED STREAM ANALYSIS
# ...
#
# [0] 📊 OTHER
#     Name: LiveAmpSN-054907-0281-STETriggerIn
#     Source ID: LiveAmpSN-054907-0281_STETriggerIn
#     Type: Markers
#     Channels: 1
#     Sample Rate: 0.0 Hz
#     Samples: 0
#     Duration: 0.00s
#     Time Range: 0.00s - 0.00s
#
# [1] 📡 EMOTIBIT
#     Name: MAG_Z
#     Source ID: MD-V7-0000027
#     Type: MagnetometerZ
#     Channels: 1
#     Sample Rate: 25.0 Hz
#     Samples: 3,343
#     Duration: 131.52s
#     Time Range: 0.09s - 131.60s
#     Data Type: float32
#     Value Range: -34.000 - -7.000
#
# [2] 📡 EMOTIBIT
#     Name: EDA
#     Source ID: MD-V7-0000027
#     Type: EDA
#     Channels: 1
#     Sample Rate: 15.0 Hz
#     Samples: 1,974
#     Duration: 131.52s
#     Time Range: 0.08s - 131.60s
#     Data Type: float32
#     Value Range: 0.030 - 0.030
#
# [3] 📊 OTHER
#     Name: LiveAmpSN-054907-0281
#     Source ID: LiveAmpSN-054907-0281
#     Type: EEG
#     Channels: 20
#     Sample Rate: 500.0 Hz
#     Samples: 65,764
# ...

# %%
explorer.plot_streams(
    indices=[8, 3, 5],
    channels_per_stream=[[0], [19], [0]],
    max_duration=9000,
    labels=["MAG_Y", "LiveAmp", "Markers"]
)
# Out:
# /Users/franckporteous/Documents/MindHive/EmotiBit NYU Validation Study/evs-experimentalSoftware/LabRecorder_Viewer.py:423: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /Users/franckporteous/miniforge3/envs/pyStable/lib/python3.11/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
explorer.print_marker_timeline()
# Out:
# ⏰ COMPLETE MARKER TIMELINE
# ...
#     Time | Type            | Block | Trial | Image                | Stream
# --------------------------------------------------------------------------------
#     7.24s | SPACEBAR_PRESSED_RT1761249643.916s | N/A   | N/A   | N/A                  | Markers
#     8.03s | SPACEBAR_PRESSED_RT1761249644.704s | N/A   | N/A   | N/A                  | Markers
#     8.26s | SPACEBAR_PRESSED_RT1761249644.940s | N/A   | N/A   | N/A                  | Markers
#     9.33s | SPACEBAR_PRESSED_RT1761249646.005s | N/A   | N/A   | N/A                  | Markers
#    27.34s | SPACEBAR_PRESSED_RT1761249664.018s | N/A   | N/A   | N/A                  | Markers
#    36.97s | BLOCK_START     | 1     | N/A   | N/A                  | Markers
#    51.17s | TRIAL_START     | 1     | 1     | N/A                  | Markers
#    51.17s | IMAGE           | 1     | 1     | Dog 3.jpg            | Markers
#    51.28s | SPACEBAR        | 1     | 1     | N/A                  | Markers
# ...

# %%
#%%
# See all available blocks with statistics
xdf_stream.list_all_block_ids()

# Print details for block 1
print("Print detailed markers for block 1")
# xdf_stream.print_markers_by_block(1)
xdf_stream.print_marker_timeline(block_id=1)

# Print details for block 2
print("Print detailed markers for block 2")
# xdf_stream.print_markers_by_block(2)
xdf_stream.print_marker_timeline(block_id=2)

# See all markers across all blocks
print("See all markers across all blocks")
xdf_stream.print_marker_timeline()

# %% [markdown]
# ## Oct 21th

# %% [markdown]
# Fixed liveamp setup and collected one terrible recording
#
# ### LiveAmp
#
# ![alt text](https://github.com/mindhiveproject/evs-experimentalSoftware/blob/main/devLogs/LiveAmp%20%2B%20psychopy%20markers.png)
#
# [Logs](https://github.com/mindhiveproject/evs-experimentalSoftware/blob/main/devLogs/stream_analysis_2_streams.txt)

# %% [markdown]
# ## Oct 20th

# %% [markdown]
# all markers for blocks and trials + methods to review all
#
# ### Psychopy Markers only
#
# ![alt text](https://github.com/mindhiveproject/evs-experimentalSoftware/blob/main/devLogs/emotibit%20%2B%20psychopy%20markers.png)
#
# [Logs](https://github.com/mindhiveproject/evs-experimentalSoftware/blob/main/devLogs/stream_analysis_7_streams.txt)
#
# ### Psychopy Markers + Emotibit field
# ![alt text](https://github.com/mindhiveproject/evs-experimentalSoftware/blob/main/devLogs/just%20markers.png)
#
# [Logs](https://github.com/mindhiveproject/evs-experimentalSoftware/blob/main/devLogs/stream_analysis_1_streams.txt)
